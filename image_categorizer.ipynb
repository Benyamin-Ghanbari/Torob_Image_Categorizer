# %% [markdown]
# <h1 dir=rtl align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# دسته‌یاب تصویر
# </font>
# </h1>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# به پروژه‌ی دوم کالج یادگیری عمیق خوش آمدید! 🥳
# مجموعه‌داده‌ی این پروژه توسط <a href="https://torob.com/" target="_blank">ترب</a> در اختیار شما قرار گرفته و شامل بخشی از داده‌های واقعی این وب‌سایت است. همان‌طور که می‌دانید ترب یک موتور جست‌وجوی خرید است که اطلاعات هر محصول را از فروشگاه‌های آنلاین مختلف گرد هم آورده و در یک صفحه‌ی واحد نمایش می‌دهد. بنابراین کاربران قادر خواهند بود به‌راحتی محصول موردنظرشان را پیدا کرده و فروشندگان مختلف آن را مقایسه کنند. یکی از مهم‌ترین نیازمندی‌های فنی چنین پلتفرمی، تشخیص خودکار اطلاعات محصولات است، زیرا پالایش دستی این حجم از داده و استخراج اطلاعات از آن‌ها امری بسیار زمان‌گیر و هزینه‌بر خواهد بود. شاید بتوان دسته‌بندی یک محصول را مهم‌ترین اطلاعات آن دانست، زیرا که در جست‌وجوپذیری آن نقش مهمی ایفا می‌کند.  بنابراین در این پروژه به کمک ترب خواهیم آمد و یک مدل یادگیری عمیق طراحی می‌کنیم که بتواند براساس تصویر یک محصول، دسته‌بندی آن را بیابد.
# </font>
# </p>

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# به‌دلیل حجم بالای مجموعه‌داده نیاز است آن را جداگانه از <a href="https://drive.google.com/file/d/1hZK1rshl4dJVEPkUPykU5cZs_ANyTWp-/view?usp=sharing" target="_blank">این لینک</a> دانلود کرده و فایل‌های داخل آن را استخراج کنید.  توجه داشته باشید که اندازه‌ی مجموعه‌داده حدود ۲۷۰ مگابایت است و اگر قصد دانلود این حجم از داده را ندارید پیشنهاد می‌کنیم از محیط گوگل کولب استفاده کرده و به‌صورت مستقیم با دستور زیر این فایل را روی کولب خود بارگیری کنید.
# </font>
# </p>
#
# `!gdown 1hZK1rshl4dJVEPkUPykU5cZs_ANyTWp-`
#
# <details dir="rtl" style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <summary dir="rtl" style="color:orange"><b>رفع مشکل عدم امکان دانلود فایل با <code>gdown</code></b></summary>
#
# اگر در هنگام دانلود فایل به‌کمک <code>gdown</code> با خطای عدم اجازه‌ی دسترسی مواجه شدید، کافیست کد زیر را اجرا کرده و دوباره امتحان کنید.
#
# <span dir=ltr style="direction:ltr;">
#
# `!pip install --upgrade --no-cache-dir gdown`
#
# </span>
# </details>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# مجموعه‌داده‌ی این پروژه شامل ۱۱ دسته‌ی محصول مختلف است که تصاویر مربوط به نمونه‌های آموزشی هر دسته در داخل پوشه‌ای با نامی معادل با شناسه‌ی دسته در پوشه‌ی <code>train</code> قرار گرفته است. همچنین تصاویر مربوط به نمونه‌های آزمون در داخل پوشه‌ی <code>test</code> قرار دارد و مدل شما باید بتواند با ورودی گرفتن هر کدام از این تصاویر، دسته‌ی آن را تشخیص دهد.
# دسته‌های این محصولات و شناسه‌ی هر کدام در جدول زیر آمده است:‌
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# | <b>شناسه‌ی دسته</b> | <b>عنوان دسته</b> |
# | :---: | :---: |
# | <code>0</code> | کاپشن، بارانی و پالتو مردانه |
# | <code>1</code> | سویشرت و هودی مردانه |
# | <code>2</code> | ساعت مچی عقربه‌ ای و دیجیتالی |
# | <code>3</code> | ساعت دیواری، رومیزی و تزیینی |
# | <code>4</code> | لوازم جانبی ساعت معمولی و هوشمند |
# | <code>5</code> | سویشرت و هودی خردسال و نوجوان |
# | <code>6</code> | کاپشن و پالتو خردسال و نوجوان |
# | <code>7</code> | سویشرت ورزشی مردانه |
# | <code>8</code> | سویشرت و شلوار ورزشی مردانه |
# | <code>9</code> | ساک و چرخ خرید |
# | <code>10</code> | چمدان و ساک |
#
# </font>
# </div>
# </center>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در ابتدا فایل‌های مربوطه را خوانده و نحوه‌ی بارگیری تصاویر مجموعه‌داده را پیاده‌سازی کنید.
#
# </font>
# </p>

# %%
# !pip install --upgrade --no-cache-dir gdown
# Out:
# Collecting gdown
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:975: The handshake operation timed out'))': /packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:975: The handshake operation timed out'))': /packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:975: The handshake operation timed out'))': /packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:975: The handshake operation timed out'))': /packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:975: The handshake operation timed out'))': /packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Max retries exceeded with url: /packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata (Caused by ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:975: The handshake operation timed out')))
#
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !gdown 1hZK1rshl4dJVEPkUPykU5cZs_ANyTWp-
# Out:
# ^C

# %%
import os
os.environ["KERAS_BACKEND"]="tensorflow"

# %%
import keras
print(keras.__version__)
# Out:
# 3.1.0

# %%
import os, glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, accuracy_score
from keras.utils import image_dataset_from_directory
from keras.applications.resnet50 import preprocess_input
import tensorflow as tf

# %%
train_dataset = image_dataset_from_directory(
    directory='./train/',
    labels='inferred',
    label_mode='categorical',
    color_mode='rgb',
    batch_size=32,
    image_size=(224,224),
    shuffle=True,
    seed=42,
    validation_split=0.2,
    subset='training')

# find the class names so in prediction time we can map the predictions to the painters properly
class_names = train_dataset.class_names
print('Class names:', class_names)

val_dataset = image_dataset_from_directory(
    directory='./train/',
    color_mode='rgb',
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(224, 224),
    validation_split=0.2,
    subset='validation',
    seed=42, # TODO
)
# Out:
# Found 8829 files belonging to 11 classes.
# Using 7064 files for training.
# Class names: ['0', '1', '10', '2', '3', '4', '5', '6', '7', '8', '9']
# Found 8829 files belonging to 11 classes.
# Using 1765 files for validation.

# %%
# loaded test data 

test_dataset = image_dataset_from_directory(
    directory='./test/',
    label_mode=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(224, 224),
    shuffle=False
)
image_names = [img.split('/')[-1].split('.jpg')[0] for img in test_dataset.file_paths]
test_dataset = test_dataset.map(lambda x: preprocess_input(x))
# Out:
# Found 1201 files.

# %%
image_names
# Out:
# ['-56lhw2AKjYI0Hnt',
#  '-6OdHXCBItIArPyk',
#  '-7241lsvPiVpNVFV',
#  '-8-0wltLEZBDTM5M',
#  '-GcrzANWUmrjk2tb',
#  '-H3eW6fAmjabFQEv',
#  '-HiiXK6MB6F1u40a',
#  '-K5ftb4XBgVegcq7',
#  '-PVsEsjibQBimlP0',
#  '-Q0Yo_MTjnhzgtN9',
#  '-TBD4tIe-a5UP1mh',
#  '-Tktdo4X5LgUMvSw',
#  '-U9lVuyU3rjePU2w',
#  '-dDdmvuCoHRNvJK-',
#  '-ga31aOTDSPAk8W0',
#  '-jatHKBptixJPEQT',
#  '-o4zntf0z1Eu0IJ6',
#  '-oeDjNxexoilWeox',
#  '-u1wASthhxChx3G5',
#  '-vCVFJtJTs7YChq5',
#  '-xAm9bKdi9qTCCra',
#  '-xq0ILJth3DVCYt2',
#  '-zJwe8YBxr85Kqg9',
#  '02OB8CEAAq0oyBwZ',
#  '02VCtYpDEvYkINWl',
#  '03DAx7-4cWGuhEX5',
#  '03xupnFJ2o_2kqKa',
#  '0BgZnLHZLYz1FmtI',
#  '0E9rEioGHMxjdCWj',
#  '0EWPPBjWdTUI9GOE',
#  '0Ec2a9JMPyN8E691',
#  '0GhwqifywrmSbfZK',
#  '0KbUyXdr0ZMjaFFm',
#  '0L0u1A_aWPUVG5aH',
#  '0RJ3OX2VBHElngIk',
#  '0VAS0qijlcyjfSfW',
#  '0Z5yioYpOoNH-iRv',
#  '0jbb92ze77YgRYK7',
#  '0r-YN2GLC7NQQcGp',
#  '0ull0MeSHKGf3pJF',
#  '0umwxpjgv3xtrzyJ',
#  '0wyzNFWaH6guStX-',
#  '0xg_-CaB8YpE3LBT',
#  '0xthRPq5IQSSb0Xh',
#  '0yyLOJ-IjDC9fv90',
#  '1FRKnFTejuYLMB4w',
#  '1G0SAiYEaHRA1ZRk',
#  '1NlN_OKl40FQC3Pz',
#  '1_b3eGKt9rlVkfQt',
#  '1b6QC4gxRbieTrPC',
#  '1bHZuYTRaquFU35l',
#  '1bt2SzdBV4Sv9Fyz',
#  '1esCtoEr2qlBQxMw',
#  '1g7BfURN3jfztN-Q',
#  '1hcP_Onwgxbq8uyP',
#  '1ojSz6gySxug4DHp',
#  '1pEVArPfN1QvPqSk',
#  '1pH-N16EKKs-iYcU',
#  '1q4rveLPqBEgRgLs',
#  '1qRddJ0MKyR7dmAh',
#  '1sLiR9Y3KXzWX0Dg',
#  '1wQICTAoPSpMCs-r',
#  '1xw7gAZfNRorjXYp',
#  '21CX7zTOyJfO_tge',
#  '21bGzJQLeUfS43UE',
#  '27Tn5EuM6Gss3i6C',
#  '2CV-yQaTTcCpQGgL',
#  '2E3LUx7GEuf5jVUh',
#  '2Exudd9ynuP4SjE5',
#  '2Hl6-HEB-jax97oz',
#  '2IO65ZMkvcDhimof',
#  '2LXcxOeQF5loaMKU',
#  '2Mb1DVI3h1BTo7y0',
#  '2OQfu4AWBw1Q-S6X',
#  '2SNqYgD0XFkddQ5g',
#  '2TtoRZPDc1PGpAZl',
#  '2Y589tmFGPZ9CWay',
#  '2YMFioSZH8uJs32R',
#  '2ar95iikaE408UXR',
#  '2oVaKd7pj74DAArM',
#  '2voJsOvAEo_ohvR9',
#  '2zVBXudf8S72u94A',
#  '33XWF2uMPSW-3ds6',
#  '350o3r_cOWzvejNx',
#  '35ueVoKg3ZfZPis4',
#  '37jG7gFwZ8dTCq5J',
#  '380NqFnHx5F0pAIY',
#  '38gRTJ9AXPVw5gO_',
#  '39J6ok1q_S9plAJG',
#  '3Di2IQCZwBoPc8Vg',
#  '3H2nM8mAeWEuZpNl',
#  '3HEl8rZKMWfuM9Z7',
#  '3OCn9BBLvFQvI7e1',
#  '3O_Du8fmtfLqkPqR',
#  '3SKpchskm2eaZjzj',
#  '3YRnxcaPs4XGPPV6',
#  '3jRFhsjPnpJ0CZ11',
#  '3kU1lE-OpOrG09WS',
#  '3ltPfUmJFLRfymgR',
#  '3mrFx34SnbRqUo41',
#  '3n46pQQPTjRRfMkI',
#  '3tCT1dXLHivVYMhz',
#  '3tmAt4tvLdjBBD-I',
#  '4-gkGuKr7F2x-geV',
#  '4623DcIlkPhWNzCk',
#  '4BwPqaSGTYcnGZx5',
#  '4EI6E7xXXSnoTfwG',
#  '4HpitTseds6ei5Lu',
#  '4IWNLjibX7JUQwBx',
#  '4JN4WVIf01yRz4gZ',
#  '4MIIqUfR5VJaAfRX',
#  '4OPOjWN2qgYHgxB7',
#  '4PQC9Latb6LZxzuH',
#  '4QrgtEUQLn9D9Nbe',
#  '4USz4lnpBlJTpEX9',
#  '4XIHJrwejdi9xu6v',
#  '4ZPHQVkTnMXVKiRx',
#  '4aDfi6t7JYBJCAUO',
#  '4eRGjKhV68DAMb64',
#  '4fKZcxZH50VaI1pW',
#  '4kSy7shZ74sOlISX',
#  '4lCfEzcd_9PBtGMG',
#  '4wYTQPjehHFzenAb',
#  '55rv97OzpiiLrNh9',
#  '5AHvsAYlFCaEzJ_d',
#  '5B34C1TBGy2OID75',
#  '5FXNiTxbmLnkF-Il',
#  '5Fo7sANLPtycKigY',
#  '5KFlpVn93HU8F0m-',
#  '5PzSYcls4aLTCpFi',
#  '5YbMUSClF8-qG4UM',
#  '5_LFBBZChdeRx8Jt',
#  '5ibeXdI0_Cyfi6ba',
#  '5nq4AvGUMAfjCte1',
#  '5oybP1-Tvcdg0siH',
#  '5p2RFwdzV9YEES-i',
#  '6-h4SLZh27fVfpSR',
#  '627wbXsFizcjISB5',
#  '6ALTpgZ3A_37BsQL',
#  '6CriuPrkDM7-Kuzy',
#  '6DKd9oweg1l9yYYr',
#  '6ORxI1IO7tnWkqWI',
#  '6PAVSkZCaIwP1hhu',
#  '6Q98YXGRLxsi-nJS',
#  '6VaxrQNuRQoE_4OZ',
#  '6bZaPpg6FTXLSLAh',
#  '6g343d9_WbJW5bYN',
#  '6h-jiHLqmlrlTXZx',
#  '6kj76RY8N1B_Ps4l',
#  '6nMHUT9WtOtejPIS',
#  '6o58lIz7ialdNGuv',
#  '6qhTDhqxlso5JhSd',
#  '6rIxNAUFw93W8ZlT',
#  '6tmKD0dWyAuelc3s',
#  '6uchZQckxU45gdZx',
#  '6ynfqdiRluOVhiql',
#  '7-Y4XyaUtH9Yl8wH',
#  '75I-EqVOhy8DIsuD',
#  '79GTqQfijUkchxGS',
#  '7DjFJtmv-8a-PxUT',
#  '7J_2w0luKdWB1WUt',
#  '7WgkG_h4CEpFAEeV',
#  '7cQ3whVyNy8y4rWd',
#  '7e_vd051sCxtjur2',
#  '7edpy0rbXLrL9k6P',
#  '7gSr69PUyL2k871d',
#  '7ggtVkdUO2Z0Erhr',
#  '7im9mKkUm-pMh_gw',
#  '7p4Qy2XNlHjkQCYU',
#  '7rDfL-487RQTrMfY',
#  '7udUn9y4hGL4pr3u',
#  '7w_OYQHBroD4aZeu',
#  '8491BdlDcF27Stan',
#  '8CDsdSTxPm-oNA3H',
#  '8DAq4SiF0KZVW7PU',
#  '8NoGe49nKzWHQSNX',
#  '8PbYtOE_5ny-LAO-',
#  '8UdXVWWqvsAswLH-',
#  '8VOwS-q25wVfF4-G',
#  '8Y4LI7b5p86E23Ny',
#  '8YgkAM6GoMLRhxkl',
#  '8ckHHc4SArANwfDH',
#  '8eAlCQzM2hTKsMaP',
#  '8kJyI1i47Z4gcGiY',
#  '8lOVD83jsC0S8h2I',
#  '8qOS4e9AVMkJUs4f',
#  '8zKuLvMrfrhGOEb9',
#  '926Gm4ehygOQkQZH',
#  '94oW-L7GR7PIUD-Z',
#  '95BseBGsKuYuBmVa',
#  '96q-c7zL8sLbyU3g',
#  '980kdZQWD5xRF6rS',
#  '9CgeoBvgWM9ryMR5',
#  '9Lg-EJA2XdzoI6kJ',
#  '9X5XBnNN3_2gGKI1',
#  '9cTQUU-RMAu2L2F8',
#  '9cna8euwRfLWF5gP',
#  '9e4TJPEcSBoTkzYc',
#  '9fH2cDRbSf4hajxT',
#  '9lV4ogjliSpOoY1H',
#  '9nQmzBJwvFZeG4_P',
#  '9o4YbecojZ4Agvv1',
#  '9qvi3uZ6KrZyQMl3',
#  '9v7eXTyFSiktKsEP',
#  '9vhkxvr_rZbsqtbr',
#  'A2kK5SbbLPanWxA5',
#  'A3q4PVimJJ3dnF_W',
#  'A4uIzYujNM9yYz1x',
#  'AErWeja3C49Uhx0z',
#  'AHbwcvNx8lt8Kv5M',
#  'AKgym3dUHoyW20xW',
#  'ANARVuI9Py_n46DF',
#  'ANkQCEIW822cKd0c',
#  'ANlT6YABgQuvbDN-',
#  'AOFdcDe05AQyDill',
#  'AR2HXO1lt0IoCgnW',
#  'ARM0qzZLGjKKZC-F',
#  'AY1i0nDWZPq-oVHK',
#  'Ac-Yd275YcoP2hb5',
#  'Ahmb1XkT24WEi8yN',
#  'AiMpFTxuRUTosgTz',
#  'AimyrnebZ7V7VRBe',
#  'ApOuZhlWB32wMW57',
#  'AsRsz4jLGsQ-ZW1n',
#  'Ay3UbF83o4MeflZ9',
#  'B2n4o-LUTgRAFED9',
#  'BOYXsFtw67OJl9AB',
#  'BWQ0rmKbihUh6sxR',
#  'BdokBH4XYYXEktJI',
#  'Be7wVvq2LM1smzNM',
#  'BipjIVf5zD_Ccf0l',
#  'Bj6vta0D4JZqCCuP',
#  'BkWYGSk6Dz8cW9mX',
#  'BoX3Dwprb6qn8nFn',
#  'BouoJYGHhqLZdGA4',
#  'Bq_EuhXfM37xsatp',
#  'BrKLsP6MiFOoxnQK',
#  'Bsan0ccI_byoRjOo',
#  'Bt0JQkoFceGcmdRD',
#  'BtXWHd2tJOhb-DH4',
#  'ByVUwbPvmxsTPn8d',
#  'C4eFR4FVG6tuXQF8',
#  'CBCtLFwtpKspbtAm',
#  'CISwPOvv8SLLhW6P',
#  'CR_92lFNI59-XEo_',
#  'CXjwImFaVvfSKcmO',
#  'Cd_5uLOVim1gb8vJ',
#  'CjyoRLtC9sW4mLsf',
#  'CkK4Z0mXTU7zfVP8',
#  'Cn0wmGdJ5NZ7jLAB',
#  'CotPA7gJ1rlSWcCr',
#  'CqSON78MpqWtH3Ne',
#  'Cwioc7xOMPuCYrFq',
#  'CyLfvCs7RsAsNFeJ',
#  'D2j375h6pyVI1MdK',
#  'D3YaGTUq0cBLW22N',
#  'D6jb2EY4NdMn5vio',
#  'DA1wd98PKZbAUBxQ',
#  'DBJGJacKfMxjSwGS',
#  'DF6Z0DXQ5zOsFXLm',
#  'DFG29jW1TZ6tRAUo',
#  'DGaJ7t5uxQp-9qJd',
#  'DHTH9fypFYrMNSfd',
#  'DMuAZiWMJq96RE59',
#  'DNAD3Iu54aIdOQN2',
#  'DNJSHPBVBRxYlgT2',
#  'DNmjPbihpV1drE3L',
#  'DOkXFAr5z-62cZtz',
#  'DZ8tWlTzDSPIxlv0',
#  'Dl6dUA_P72iaV_Gk',
#  'DmZ-VcA9ZZYxm8zj',
#  'DryYrEKg9Ty0Bgb4',
#  'DstUfi-DLRRbrP3B',
#  'DtLODVkRoQKRg0O1',
#  'DuG437zzWhxT4F1C',
#  'DuuQIrqQHbK1Rzo7',
#  'DwGQuHf_CUvfnytX',
#  'E94WHDtREg_4UKx0',
#  'EDCt8y5vsVRL3lLB',
#  'EGauwIJ15F2VIQtO',
#  'EIXV8lsNugbXnuNh',
#  'EM9_I3yFs1iSgbDl',
#  'ETa1lqhM-2SA6JDI',
#  'EbKt1UMo0q2KNSMQ',
#  'EcTDPh5m43PspXm1',
#  'Ecshom3CCxgqMvWn',
#  'Edn95JAgP_say1sJ',
#  'EiUXMfXaWDkHTDgy',
#  'EnLcWfGttS1qtadr',
#  'EpQZ3frs6Uu6f0a0',
#  'EpSMyKQzHvBgobkE',
#  'Ew_VFXN1-fpyXy0m',
#  'F1FH7jMDGjGK_LYy',
#  'F6ulKoGxnp97ms9A',
#  'F8q1MSFCfo17_pFq',
#  'F9u5wOsKPxsfqx01',
#  'FB0MQJUlljHnQMbI',
#  'FCKViAr_j2bGNad-',
#  'FEdO1zGd78FI64_0',
#  'FFgpeaXufRHDg6EV',
#  'FSfoLOKV0gAcKjc4',
#  'FWQTPQoCGtlG6WOc',
#  'FX8HuVL-tPG8WQwz',
#  'FZgM49xig56LsNO4',
#  'FfojmXjNzIO3LlqK',
#  'FhgsCcPz6nUVOIga',
#  'FiI8oTUE_PLwfuTe',
#  'FiYIazKwoYvhP0RG',
#  'FmTxV2zxW9A_QOJx',
#  'FmWnvnYfagNgJyS-',
#  'FpdW4axUm7rTvvGp',
#  'Fy7RtntM4Ynl_n1-',
#  'G4YA8kYlU65kXLkf',
#  'G5gFrVCNgEPQ5KGr',
#  'G6jXcy9Dej0YLw3O',
#  'G956mLo7WkUsKXVK',
#  'GEcGAlbSdD0UoBDO',
#  'GFQ28Uo-SZVE_ZNV',
#  'GHJq6QDSfHmsCdkE',
#  'GNea0QBvf-7iRjCV',
#  'GPy_MpIHGOtAvTvA',
#  'GVA35YnRcS6PAJj6',
#  'G_EXYAaGLqPtcJF6',
#  'GeFEXm--sdo40hVC',
#  'Gky5pvr5C5pSMU-K',
#  'GnL94XPPwqljHu1f',
#  'GrdIVxJ6i9boTli-',
#  'GyrO0c-efCuNcLZU',
#  'H-7R7b1tJaTNZR2t',
#  'H4DbP_RRNnYCJqNu',
#  'H5qh4ILVheKeQTrc',
#  'HCdbMZI-FxewLSsm',
#  'HD3EIvOX5kIs1PHR',
#  'HDZyPkZYXiFfzGYc',
#  'HDqlNzKFk37cI5eL',
#  'HJM7tcM3BHjMvffl',
#  'HJxxeCjXPBuP_qVt',
#  'HKPd2YBKSbPBpYrv',
#  'HNvGp_lo0CLvRjwl',
#  'HO6W1Aug4gvjKBtD',
#  'HOa3aA84aJqJQOZe',
#  'HPSziRfdg9vO0rGE',
#  'HZ9wS0DDREpZqDKg',
#  'HZTJFrqEUYVTWsn7',
#  'HZYDZ_wOO7P-8ur0',
#  'HeHym9Lo6KWp37WH',
#  'Hf_VOJNtW4lX5FS2',
#  'Hftb2e2ndbj7Jp1k',
#  'HgyAUi75nzCR-e_Z',
#  'HqvUVlQzW0He2e4P',
#  'HrFAYUX-NSeeN9s6',
#  'HuMcd1nIfFMo_l0x',
#  'I0bpbYtAEz-StIQ4',
#  'I1sgtftgVw_aPs9L',
#  'I6FstGt0E811A_Z8',
#  'I7xm2HCcb5UDi4Z2',
#  'I8cEz9UC7Hxl1xCa',
#  'IBdi_Sq0AOvnasIm',
#  'ICp6zDvkyCn6i3Ft',
#  'IERLR88RDdUWA_xh',
#  'IINv9DBw2c21YTuw',
#  'IKVSZHhMm-jKgSrq',
#  'IQKXMoZQJX4-eMts',
#  'IQT910n-qZo410_v',
#  'IQvqEQi46_dh_WAj',
#  'ITGMBMOLPOF-Mjy4',
#  'IVgr55IuLnywnYHt',
#  'IYBkl0VTknw42B1N',
#  'I_qNyCh_b5G-NISX',
#  'IfzfVRA4Pj6HEB88',
#  'Ik17LHLFmmvPBUi1',
#  'IkOP0vRUXQ6DaNRB',
#  'InDPY7S2EuzO51Bm',
#  'Iy9-4TXwz5celvQw',
#  'J-MRBc5e5VQAe9Ct',
#  'J33ovOgW0PaDpz7W',
#  'J8w2Sua5wQh2hQt7',
#  'JCbvoazEd5yohc3v',
#  'JH9OYupOfjxZpUoN',
#  'JIk44tGexR_q-FZ6',
#  'JJ2ogtwCNWLqS1uI',
#  'JQx1PnnXs4bNIBdA',
#  'JSCLR3wxwAwfiz_a',
#  'JUd8IiDAxpgDSRiN',
#  'JYuM4XgsCj2I6qSW',
#  'Jb-S1qWsggvkbWUR',
#  'JeUP7s3k6RX1Y7Ix',
#  'Jf1pMZAj9tVWEoVg',
#  'JgL3Lxvnq5HPlye2',
#  'JkYUbpJrg65AAX2u',
#  'JlnAxatfUVo5ep4k',
#  'Jqz0QhhpeCeDK9lV',
#  'JxBgb05DE2zGdWhg',
#  'JxMyoKmynYgMf31m',
#  'K-zq9vVaKtN9XHPP',
#  'K4gYBTamBWSk8K5p',
#  'K7B7xTBjU4jOK6Zi',
#  'K9cPClfy245mbvZd',
#  'KB0h7f0DGSXuIBoV',
#  'KBET8hYJnU84DTh_',
#  'KIvtjWVHffZ4iuAf',
#  'KKobjYlZw8n_OOnu',
#  'KNbgeSPRcwDmMzdM',
#  'KQeNtBjtw_jzepQR',
#  'KRIAkvOeKW-urW5O',
#  'KS714PtfSYf7cgI3',
#  'KX77Hi6ZECJTrxiU',
#  'KaUTU-3IMwzGRqtz',
#  'Kal7ke327u_dgbIW',
#  'KbDvj-Qf7dXt543K',
#  'KknJEp_uNXapiuO-',
#  'KodKMLklKAYgvRKv',
#  'KsHw1sIZ4aLLhjae',
#  'KsZDeSIe6ysaIbYO',
#  'KuZBRfx8EGIA452d',
#  'Kw3Nvz53ijsd07XQ',
#  'Kw6Rm39RXWDNDupJ',
#  'L1FuIXyvAEGr6YC8',
#  'L1fc2XMsdVqKspsd',
#  'L2NjaL2n_VOYm-cQ',
#  'L4530sbw918whVQK',
#  'L6R-AXsc06vEmPcl',
#  'L6_lCUHVSfeOOWW6',
#  'LE4jzOzV0jEehCpP',
#  'LJ3EqcwZI81f02Sh',
#  'LKl33GM1f7B5U3LA',
#  'LNTKJY447y-eJj1g',
#  'LPs1PogzU0EftGn2',
#  'LS6Pg_1CVqSQ6hyl',
#  'LiRKvKHJuf0LT1Eb',
#  'LiXF08cvIORuIHzq',
#  'LivY_00dlfzgUujE',
#  'LkYbitBJQ-EHLbBq',
#  'LlN4kf45g13uqojV',
#  'LnuYCfl4OtK1Zerp',
#  'M3cGWXMROdcFOYkw',
#  'MBmCnhomhvMMIG7D',
#  'MIYbj9m4Mus7TDBr',
#  'MOHBuoOTK1UzbpJi',
#  'MOddGeJtjSewK7Nd',
#  'MXIgGTp7i7p1qRTK',
#  'M_Azda3NzS9SV-WU',
#  'MdD58XjqvLyqsw8-',
#  'Mpz0XiH0pic9tfx9',
#  'Mq1mxP_KTwuzdQu4',
#  'MqbYBh84jd1ikM6w',
#  'Mqq2A2To-qhfMUXo',
#  'MrWLH33aC-XA_za8',
#  'MurCBDLchmWRZySc',
#  'Mx2Cvxfc8yqxjLoh',
#  'MyjhifuP-JzQA1eA',
#  'NBQNoxISXnOxz8Xf',
#  'NG_vjb7kXtjjTAV_',
#  'NRjzSMSJxkKRwaj3',
#  'NTuE_AlK61gE_BJX',
#  'NXI54blyfgF-_iPn',
#  'NfJIk8eN3KzXgPrF',
#  'Nwlv7GSjNoS5EwDc',
#  'Nwy4-Dqc8kLBh_RP',
#  'O-BK_nIkuqIGtiap',
#  'O-EhJSPYkL8031pf',
#  'O1Q-tou5LLPLVFEn',
#  'O52XBgeuiZuJnt_c',
#  'O9-aNDUp3Rj_wNXu',
#  'OAa2qOwqWbChVCXK',
#  'OEqBoN6-79SPo7uO',
#  'OF3V2eYCyJYxSX8y',
#  'OMDLMkqFe6C4J7fy',
#  'ONMX-uxRqvrGWyzK',
#  'OP6V8U24DAn9lWKi',
#  'OPClMdy5yCx1Hbi7',
#  'OPxcsFZmUlTHYN4J',
#  'OQWQIgA3OSGRpJNv',
#  'ORHbGpCerG3KIMTl',
#  'ObRW7hvb47EJS2SV',
#  'Od8gCAgSlIj9nNbO',
#  'OenHbnQPLAlJbJqY',
#  'OlQdnHqoWB1HXTGv',
#  'Os6-8yjTA1UZZTJ6',
#  'Ou-LBqELX6-_qBBL',
#  'Owi2C-zcHKG-fr_H',
#  'P2RxXhKyRf7Fm4Nf',
#  'P5htnkQaDlVrWSxR',
#  'P6P7TvcxIXxZMKV6',
#  'P7Om9AYiYQEMP2UZ',
#  'PADRX1wKwb_U5hcs',
#  'PBK6185UKs_qUte1',
#  'PBr94wIMtCjV8FiN',
#  'PBtrhSvv8FtzjMLV',
#  'PE7lfMOg-4E09VDE',
#  'PFRZtGExjdeAavL_',
#  'PHE-ZjPb0h3KjtYt',
#  'PLnQH952QtQbtLsm',
#  'PLsnskfYHuTekHZG',
#  'PS1x7c8jolhVU01A',
#  'PT1ZJTvAzw79T_dY',
#  'PU0EtVbKwqPqKCl-',
#  'PV-pClMVmqojMM61',
#  'PkSr_jzMJtBQyxDQ',
#  'Pm8LlbQ2rhRDxpAv',
#  'Po4NCiuK7w_TIZG-',
#  'PrHz0HwUMs97lKj6',
#  'PwDYuW-MH-vVG6tx',
#  'PzaYCJejrEInmIPW',
#  'Pziu4C04oi28-kQ9',
#  'Q12XebzZtgwmdRLz',
#  'Q5HZTMOlI1eUf-bx',
#  'QETrWUxyrlcgG8T9',
#  'QIIOufzLjdpA3p-h',
#  'QPV2st2AWMrfASgU',
#  'Q_iFzrdqy-BOImvU',
#  'QgsXGMpWq3khad9R',
#  'Qkl1LpRNN_NefSdP',
#  'RBx31kiDT9v5mhRa',
#  'RHyc47MvcEfxJaIj',
#  'RIsboCBXBWOwsu6S',
#  'RPLw3khplw1Vo_tE',
#  'RQuqZWIdjTro5xoS',
#  'RRKtSnKIqtUPbBd1',
#  'RW_TSPCuup237Bb2',
#  'RZHH9mMZD38qUCzS',
#  'R_i2JNJO51osiv2q',
#  'RaFol46w1nJe_kov',
#  'ReRAJ0ZlxW2LLgm3',
#  'Rf8t48Ot_xcZr-0N',
#  'RjfeqgwInHFviUFh',
#  'RlP7hro6BlcW4rTJ',
#  'RoRxQoRnW-3MJZ-P',
#  'Ru1J-IiU_i5W6uDe',
#  'RvPnN3sZ5TyVRW8g',
#  'RziQEO-CPgwTtMo1',
#  'S0wTaqYf15_-cQAQ',
#  'S1-nbmcLR1R0P1Jh',
#  'S8363VsH7l51u0JW',
#  'S8NZJaAUc9NiUKnj',
#  'S8iueyk7PktK6ed_',
#  'S9VhD-NT2S1hPswD',
#  'SFIMYz1cqJEbyMGE',
#  'SHP0n86wP_-jHa8P',
#  'SHeGgMFvb4g87PFC',
#  'SP2fGdFcw3LQLV_P',
#  'STWrkLEKX0hjrkRk',
#  'STcBEAjaJEXFL-n_',
#  'SdoYx154-qWqOmce',
#  'SeJwyGwOSx9HAA3M',
#  'ShI9iP5Hcq8iQZHc',
#  'SikkNTkOxbFXW8__',
#  'Sj1a0pgAovl6BuCa',
#  'Sm1_8r0k7M3rxF-8',
#  'SnxM06sxIt0v83TL',
#  'Sw8B8sN_cth4RSYg',
#  'SwR5bJddkwEyvnAg',
#  'T33J7H9TdmTR85zP',
#  'T8xBLJAQ7UdbCDnq',
#  'TCAKc-IJT64-5foa',
#  'TE-DKUhoqidwGEUn',
#  'TFdFuh5Wtp80FlG8',
#  'TGjpR4vmJOdEK80Q',
#  'TJ5u75_kHoWHBvur',
#  'TJwJPXiU4gkIVdWf',
#  'TK4nargLXMpDZF94',
#  'TKJ8N9p22i7GNi5m',
#  'TLEUdz0hzz31L29f',
#  'TM5yCitnoNI0oCPr',
#  'TRB2-4c7aF_vsJ6N',
#  'TSPGOEdItgDmUHx6',
#  'TgZ0-IbnxHwAhhls',
#  'TgrRED38ttQtUAan',
#  'Tie4pCtdHYIiZi1r',
#  'TiuWnqgt2CvHFFhJ',
#  'Tj_RcEcJPTGSOxBo',
#  'Tk8z9x8auXYPn2BM',
#  'TkjZ8H-0e-FdSJlc',
#  'Tm6Hn7iR3Wjg7tt_',
#  'TrT5pFQ1DnsyWpff',
#  'Ty829M-Znv_sssa6',
#  'U4glu4-woAqyVjbT',
#  'U7qhu4k7AL_YI7Tq',
#  'U8YrcltM0XtjE9zf',
#  'U8_5TQEjPrbMKnbT',
#  'U8qLDx94zVkD0Tpv',
#  'UHBqEzoMxq4iOxG5',
#  'UJKD2orDb8NszHj6',
#  'UQ2wS1PLYGtWua9Y',
#  'US0WJLDat9iKEZSt',
#  'UUcyqkNo_HM-ebWC',
#  'Ud5dD3kO-4cvU63l',
#  'Uh3K8IJ7jOaUBOnn',
#  'UiF3DWjhO874WeUZ',
#  'UitK8Bv_7-82mXW9',
#  'Um9yLl07K0m9VKDH',
#  'Up8V7gDbLdQAftnL',
#  'V1b_fTkscLmdC5fm',
#  'V4FZQe-av52h6r36',
#  'V8LtFKuhxO2R2xQV',
#  'VAwZfn-zWA24rKDO',
#  'VBHmezUHUSzaiWCg',
#  'VMbGXaTIeyEij48h',
#  'VODvvMnkm1uQQZxL',
#  'VPbTPBr1CwC3UEwD',
#  'VVBR9uONcW3hxuVf',
#  'VVVEDQRhhPz2860r',
#  'VYcBYxPHBp6lYyP4',
#  'VZFbeyxPwe_yViPW',
#  'VZVbQ0RFtN7bROZX',
#  'VZgsVTsNPERD64d0',
#  'VbcTerWAiecU-_T5',
#  'VcdD-YWfLw-EKRP3',
#  'Vhdd3_zb0x11aZYh',
#  'VlKdd1eUZ5AEatmm',
#  'Vm-h4P2PQJV15vPW',
#  'VnOMWUc72TX9z5h-',
#  'VrBfBAIWp6WFJT7-',
#  'VrWC9y46bFXV-mzS',
#  'VrcewP8zC-loLPJ0',
#  'VuM1Bh6cjTQl60u-',
#  'VxZa9MutAOUc5zvc',
#  'VzoQaO-_7DZHdQ-o',
#  'W72PD6YAcouB-FiL',
#  'WE23pC0zk73JN07W',
#  'WFgph1pN8UahquY-',
#  'WGcnmtvUrXzMbkns',
#  'WHGlrlBuAUAuTng4',
#  'WOh_n4oB_wubjlW8',
#  'WSAuWYS0XgwjBhbB',
#  'WTRQ7oLsXbkaq33M',
#  'WVCXBERw6a9b6Q5G',
#  'WVGcjDpW2TON0ZZo',
#  'WfoB2I6tgIB8e3j8',
#  'WgXMyPXOcHO09hzo',
#  'Wkf66W7HTyTSJove',
#  'WnBfoqZVMzOOr_bk',
#  'Wq8diDtBqWfuVNeG',
#  'WtB9uciQZvFdfLRI',
#  'X1BNRo6JevZnPXAJ',
#  'X2FG6CyQQk6oftMI',
#  'X2f44zJsoiFXBnJX',
#  'X3WEspkGdJVAMBKq',
#  'X6C_LM_cpryt5nNd',
#  'X6wq174aw9BmI2SQ',
#  'X8wXu8AqxMPXBy-y',
#  'XAJsLkUzSaYW5g4n',
#  'XAPrsL-d-F2c17Sa',
#  'XAuCdsmCyucewD3m',
#  'XBH3yKbU_jAIVZF1',
#  'XD4ImTdc7O3__7zn',
#  'XHOLg02yITULLjiY',
#  'XMdt6Ijf0M5DFBOm',
#  'XMe9zNbPW6pR_pDN',
#  'XMzgeoHxZ0O8Oqec',
#  'XNpEa7TcEEuzutsi',
#  'XO4WRpylRilw6xmB',
#  'XTVQW3n29Snx_Vim',
#  'XUBWx5t5bWSp7jZT',
#  'XVuUX_8JXbJki2A2',
#  'XZxXEnpHGNKd7Pl6',
#  'XjknCRHoUaihjA8M',
#  'XlysiFNkOvyooI4L',
#  'XmBFnq-HsNw8TaGh',
#  'Xw8PMrBRWu-YzkS_',
#  'XyxOwyfX3LYAluoa',
#  'XzAw22prrpETudgg',
#  'Y-US858g5BH1mXMo',
#  'Y3wq-Lx75bO_987A',
#  'Y4bmKMgtWyTpaehI',
#  'Y6RabkpuTC-eNL4j',
#  'YAdlfMsCUe3w5l6Y',
#  'YB7WU1m-kmDfhjrg',
#  'YBBD3k33YPQsUH5E',
#  'YBa48SccnEnLeJQT',
#  'YBdovNpgKmc08J_D',
#  'YH_dv-yZB5V6uQMZ',
#  'YLduUB9y1fOlVU71',
#  'YOewutgnKiBHRZZY',
#  'YSUpek2x2hMnaCM9',
#  'Yd3OX4adbFpYPRLX',
#  'YeecROr50l0eQt-K',
#  'YfDiAmnqvM-I3ZKq',
#  'YhS8lmqlwA9kf2TE',
#  'YhvuFNaZ9HKsrHRV',
#  'YsUW5vslxYTsHPcw',
#  'Z1-Lxtn08bhoqwCR',
#  'Z4CK3eZU0rpsAk8R',
#  'Z7uelPbw9UgdYjUn',
#  'Z9l-a5dsMn3873Uu',
#  'ZKTwUoZYvxtbAb_j',
#  'ZLnZ4eNyNsqibVtf',
#  'ZNBFMS2CV5K495l8',
#  'ZSQwF1Me-j5ZV_xL',
#  'ZTt0xOx48oLI_VEp',
#  'ZXrLU3okF1vwew2z',
#  'ZcYYFHwHwiBrCC89',
#  'Ze29sVAC_KGEUJTr',
#  'ZeE2Mv6WtokRebQp',
#  'ZfEJABLz81gEJZFL',
#  'ZiBKN7k9qgkz6CmA',
#  'Zllc49cjw1kCJDSB',
#  'ZmuY2cJEwrOjTSYH',
#  'ZnGd2r2hEVFMG-Bk',
#  'Zoj7yt6UdsOpukfS',
#  'ZqyzTOdr9uAGxuhU',
#  'Zr3a8yi9rAEUuGhr',
#  'ZrRbpcktuj9GWcIK',
#  'ZsP7dO1ZXae9vIkb',
#  'Ztq2OCiRKeqiW0cF',
#  'Zxsti3rf-tUeXFZ2',
#  '_-_K2eqZhHDOwZvh',
#  '_4IrR0yhl21gQJC_',
#  '_5YFxLhFwGYSIgsc',
#  '_6skJ-ev8mdRVvGB',
#  '_943MVifa3ars_IH',
#  '_EBUL7Spyo_V1jy1',
#  '_Hcb145r4APSCmQc',
#  '_MrqzvbI3-MGeKsd',
#  '_N-x7yIPgyWzJU2G',
#  '_QL6CiuXlIIb-JY2',
#  '_WajlMwUDtI3lsZS',
#  '_Xrx9f_4DZKreKSA',
#  '_e2mVi98Mcn9Vn9l',
#  '_eKDb1gw3WzE70mj',
#  '_eiZbeEPqC2MVHff',
#  '_jAG9GTzHxnUUi60',
#  '_quX9iNaxeDlgG71',
#  '_wrz8lr6uTXldAzh',
#  'a2-6Kx2APx9LetQG',
#  'a32cAtNzr4M-j8s2',
#  'a70IODXn9p1F_-n2',
#  'aBcDR-tXIGQ8KoGQ',
#  'aGBcax1l33c15uZP',
#  'aKMK_7dmFb9DjbY5',
#  'aKoXOOoNaXhG4WSj',
#  'aMKpGFE6QdAmQuHf',
#  'aNtYH-q_he2rYgqQ',
#  'aSuel9dbdVIfSC32',
#  'aU1gwjoz-WiHgm8N',
#  'aVzEkjO28rYHfOCV',
#  'aa8_Hh3jAu8EBnP6',
#  'aaGLoqAf8c419-KO',
#  'adVJJzrkhgxRvCSg',
#  'akVo4ymIVkxhZa8k',
#  'ar8b2a7kKNCOluzW',
#  'at0bcsBmmbc5ETLK',
#  'avn76kWZr1qLTEP5',
#  'b1zHYAw1c1-ac1IC',
#  'b5pHQ84NKTffMCPQ',
#  'b9btDG_EA5qFpnYj',
#  'bCU-9BhPB8iM-PTp',
#  'bEEMuhdWjLrV0ed4',
#  'bRgLHDmMAM5VprB7',
#  'bUgPq3yi__DQIM4P',
#  'bX0OLhDYhqRuNhFm',
#  'bYMWcWETne4kxkYh',
#  'bZwD8zUZ4GM-WRpo',
#  'bbXO-TCuSME42gWD',
#  'bhqQRaSmg_VAs_Il',
#  'bixEQqZqNXsYx9Ao',
#  'bkuSkFsVDBNPcHb2',
#  'blC3wcN23ENbkTDp',
#  'brm_rdPY1myLMAfe',
#  'bsnF7t72aVPEwp2W',
#  'bx1_wH9vFhqvQcV1',
#  'bxg8Zt-oGZsnneAm',
#  'byCNff2jRr5PwqPc',
#  'c3bDajyBbdMRMUxz',
#  'cDvaq48VqszcNORL',
#  'cE6WMpv0im6KGFaM',
#  'cO9-3epDeWkqCmUt',
#  'cTrm9LIeuzOpV26i',
#  'cVEfOHA6TBRkwaqD',
#  'cVnncGaXQqYAPchj',
#  'cXVBhsBaS9hYymZz',
#  'cYhK8AwDi1JBEL1q',
#  'cdQHHAGjCiefjmgl',
#  'cdxFr_oCh6akvhD7',
#  'ceLK05O6ijwYV1bV',
#  'ciWWzM7x-Aykcfyh',
#  'cjAOGXY-Dmif2zxy',
#  'clHC_kJrGbuebPWC',
#  'czx1KSd1l5gWTtw3',
#  'd2QfAVdtRHTgmvgx',
#  'd3PQyYrZ7rjPUwEq',
#  'd6B7auIGqaqkcUcT',
#  'd7KGsw5tgJtcJtyL',
#  'd9I-S4LprrdlidsU',
#  'dGZ2uA99tK9HbS_e',
#  'dICxk2RnbLig789P',
#  'dIbXW98MAkE1J9n1',
#  'dJYSzf3kCWqn3XuI',
#  'dQ2YNm3SkSg-1GMz',
#  'dS52D1B7bgjV_3D4',
#  'dUlAvnOJhTVSiEYF',
#  'dV32SyY2jduZNFsN',
#  'dVcbQ7QfhVgYed2V',
#  'd_cETczNPjSPfLAl',
#  'dawIjKI4aUPa9sIF',
#  'dfC0iEDHkgt8vcpR',
#  'djcamuifUHzWGChA',
#  'dl_J86axaELfdTKr',
#  'dmtYOAS4aQeAaJ1C',
#  'dobA1omUtPz0K1sd',
#  'dog5g8is9XWbWOVv',
#  'dvSG_52oN3DJu-ts',
#  'dyvHqst4XWp32xAz',
#  'dz6vI-cFBJxae0JE',
#  'e-bPwq_oHrxLc8_0',
#  'e2uRX2ku2YKOUX6A',
#  'eEJ2_FgI8KeP9MQ-',
#  'eHwxnEn9FqPT_8UC',
#  'eKIFdpuPWWbLLTrV',
#  'eL2f_9A4KHE0eInr',
#  'eN6olfwO0xoXM88a',
#  'ej5R6MSbhkTYPgbT',
#  'eo1qYOE4yMBs0Xws',
#  'epYXUX--3wJbp82x',
#  'es0yPv2cmWsWCMSE',
#  'es2XIP2ccHmkSvRQ',
#  'ewSs3XS-c3YzQ9CF',
#  'eyfOCwbdrZvkGTpa',
#  'ezq3lFXlc6s811Xk',
#  'f5jDNl6nuiFvujZy',
#  'fH5scO6-q_d2BM9F',
#  'fL1Hah8gKM7VtbwC',
#  'fPpmrkEJCpiICCOS',
#  'fz9DpEohmKPmYVNi',
#  'g0o_ZHqlvyJQu6sw',
#  'g7CEv40pMDMKOiNb',
#  'gABGT1CoWD8CER4a',
#  'gAaWF9fQrP0w30Bm',
#  'gBMkEesrKZ1CWPR2',
#  'gCkCYLqmXvPaJe8i',
#  'gD1cZ4DxzTbIUfA_',
#  'gDNEilJat25x79y5',
#  'gEbe4a0ao-ut8nC5',
#  'gGDLejoVpSGX9hJ3',
#  'gHdJKoD0LdK0l1Q8',
#  'gKN29l6AcENpxLdn',
#  'gS3ZLbf2yRSmC5AE',
#  'gSlvDkV1qPy16_tO',
#  'gT5VQky6qwdeyTOs',
#  'gZK_vgNYF-X_PMyl',
#  'gb9MdCei75EcYp-t',
#  'gcMP5xJpxGzWy32F',
#  'gcPVRtzhvbo3CE-6',
#  'gf9J6KBZ93RPXoIq',
#  'giJ4T92mTGkLdBul',
#  'gjjp7UUF3Sn1pCKq',
#  'gqO4xVtp-a4in7Mn',
#  'gsSj-hoM4W9YVmsr',
#  'gvRgGKhT3X4NaIaO',
#  'gvvln0OIQgGamT2P',
#  'h0MkS8ictRE-qYCr',
#  'hEWHqSQL-O4YYCb9',
#  'hKLKV9v_IZuSov-P',
#  'hKUc-GDD134AmAUr',
#  'hWZN5vl_Y_c8nqGa',
#  'hXx535BVnPx5vIPw',
#  'hZuQK47sZvYDjoI5',
#  'hb4jg1RSse_3t3kU',
#  'hivAAcGProj-Kf59',
#  'hroXa7nYoElasU8X',
#  'hxkUYq1Y3GPz5HwP',
#  'hyudCSy8n6lvubGx',
#  'i0ELKUNiwHiallQG',
#  'i39xBp8eTpzh_S5R',
#  'i3cOs7pjXUxdqE0h',
#  'i3jCCygYc4SiipEf',
#  'i7KEpiRUSbsf-PO8',
#  'i7mHVw2AVgMHcjOr',
#  'i9mN00ODPA_6vwS3',
#  'iGpPTHFWFnfAgvGi',
#  'iJuvTGJjf1_S4WAV',
#  'iK-gbcFfVex89oBZ',
#  'iLeb0nSuYlm5SwJS',
#  'iMeEPgyLb-dOJRps',
#  'iPNgnDIwJmsKPTVI',
#  'iT0_5lP2HiAvmjBX',
#  'iUBylvH05TBCD-Pl',
#  'iWEAiMiGJnq_BJHZ',
#  'iXWRVPCoNKq56HeA',
#  'iZZ4sGt7iNkj0w_G',
#  'idUMZESXmE75l8Lp',
#  'idfp7natdejZVx_L',
#  'ihUBgkCEorEBWi0V',
#  'imHDFc9w2o-hsws4',
#  'in51JrYky2jW8-Si',
#  'iqUiwh_twmh48rVB',
#  'j0u8giLVqgGIfKcJ',
#  'j5JyyAvwBr2uWues',
#  'j6i8xE1cvcpfqevL',
#  'jAQGvL7r9Wi4mp7k',
#  'jDPKQkCbNRvDRQGT',
#  'jJ0GN18yZjjKc00-',
#  'jLP5RFmES80HnW3X',
#  'jUDhcx1LwKuJyjkm',
#  'jVcyrjfOIL01V_NX',
#  'j_ov3-BfKiIF-Odv',
#  'jcc8ZHFs11r9x6ev',
#  'jdlZXmSf3Bj7YrUX',
#  'jhy6C56SNOEd3B2d',
#  'jvRdmWcK7sjL0gT7',
#  'jz8wG4gotiG2P1t1',
#  'kAWhOMMDGZno1gKD',
#  'kCbW5yT4YwOjrz9Z',
#  'kGW49xTLTmAH7-dZ',
#  'kLSK0hTeo7Eios-l',
#  'kP1m6OfgxvqzP_jH',
#  'kRX3rKsX8tDjYY2_',
#  'kVBal-DyEbHtI2y7',
#  'kWbMUxGeQwUQndCp',
#  'kYyu6yuyDk7GxYfB',
#  'k_1Jpq7J3IdOfHWl',
#  'kcSw_pOBefUV8huz',
#  'kcchX_xctTciA38A',
#  'kmWRBkTlNoFIfUB5',
#  'knctHvqi8Bk1e2RT',
#  'koYyjY5JLKpsRnGe',
#  'ktXA0heFSXy1sTHQ',
#  'kuIsiy0ygleQ1_h_',
#  'kw_7vRHn6Mso0R5N',
#  'l-qX_MLDuHlR6NRE',
#  'l2yk5L_yIqD7ks59',
#  'l44TxUUj_s0pF3MJ',
#  'l9Bk5VXQmM8d26t3',
#  'l9d8ONvlW0IWj2Iz',
#  'lENUBBuzOk-2ytul',
#  'lMbT3BMbZSrboe2d',
#  'lNn04ALTGMHQrAzw',
#  'lTPnJaJP0_3IpRQ1',
#  'lXq8769zRWSaHwq1',
#  'lYOmpuqUI9MEKCw4',
#  'l_7yvVHmY_venrbd',
#  'lcQuJpLnai61obSk',
#  'lh1P5_mvsibO9vKZ',
#  'lhVjUZa3Ewl8cg5Q',
#  'lo7tegsQ5uuVJNuv',
#  'lovgPqTavpVaI-Cp',
#  'lqUe8_y45YVg7x9Z',
#  'lzpMi9u2-hK80Wwz',
#  'm0F2pe6AW0Lk6xpd',
#  'm0OJ95NJImCETPIA',
#  'm0YodyzUZ_FxXMNe',
#  'm2neIwIuNy_ue3nU',
#  'm4uis2bVeFOFE3tl',
#  'mAv3fcd_OXHLFI7V',
#  'mDuH45cwUTYpZPXq',
#  'mKVKnmiV29EndroL',
#  'mMOT6I86w5xv1lIv',
#  'mVoLD0Q7TNFcji8Y',
#  'mVr-EhdaDlS8cw1F',
#  'mXVCGhxFVFm3UQzM',
#  'mZ85OqnzeY3bElLC',
#  'mbB0GkwmYMFfELpN',
#  'mc4UFdKIAuzZQdGR',
#  'mcq-ee8CM7ysdryF',
#  'mjIUfbsl2fxQnApA',
#  'mm9bY2H6iGn-pTiE',
#  'mrjB1xj7-Ztlz4hu',
#  'msIeP9LJeUlejVN9',
#  'msf7r2SMbcfWQhH5',
#  'mtg-EF9GBDnUeKws',
#  'mxAyqDI78Sshe3nR',
#  'mxLcgCmWhcdESBjW',
#  'my8jjODNU-UZDn_m',
#  'n08fRXHtTSUsaal8',
#  'n2Hy6XY5dTyiLK_i',
#  'nBLqWe8OqQi_LsVf',
#  'nITVWpyeTVveHQ50',
#  'nIXcxGPVhxrA-UDu',
#  'nNDyAlROhT0ROePQ',
#  'nOV4-JklUvxd2zav',
#  'nP7BZdU8iYX1pSGp',
#  'nPaDFUdDhncqnkyW',
#  'nU8Lg88_z1TjpS0b',
#  'nXxymLiyMsz75st7',
#  'ndDHO9nrj2wucyec',
#  'nizhfa1ZCTVvOmsP',
#  'njUcRRtmO5dHdQTe',
#  'nmpTiijT1cnJXRSL',
#  'nq3P6g9WeRUmShaX',
#  'nqlwSrJ3HStZzYmW',
#  'ntL-gnmI0NCHl9Oc',
#  'nv1SGwWvRw9MJu2k',
#  'nws25twa280bgL3_',
#  'nx68Uii-bw8LNZAa',
#  'nySap6289i8P6vBb',
#  'o08idUAfuSEOo4UA',
#  'o12TMnXbEHffq95h',
#  'oA21flEivhSwJdnS',
#  'oB8MA-Y6-IsnrBA8',
#  'oHG8v8mNTR7xCwI_',
#  'oIGGo4fPfK5TYEpO',
#  'oOmM5Ad5l33A_ifr',
#  'oQeHlJXGGC98n7jb',
#  'oWxS8OqIlrK0I_46',
#  'o_2eM-ZMaHp-TikF',
#  'ofDBNlbHTD10Me6Q',
#  'ok0Q3X77GzRg7wU1',
#  'omecYj6yFieFlfIf',
#  'omg6pabR8T1_ew5X',
#  'onGf9nCIuJNyKknE',
#  ...]

# %%
train_dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 11), dtype=tf.float32, name=None))>

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal')
])

def preprocess_and_augment(image, label):
    image = data_augmentation(image)  # Apply random flip
    image = preprocess_input(image)   # Apply ResNet50 preprocessing
    return image, label

# %%
train_dataset = train_dataset.map(preprocess_and_augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
train_dataset = train_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
val_dataset = val_dataset.map(preprocess_and_augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
model = keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Add your custom layers on top of ResNet50 as needed
# Example:
x = model.output
x = keras.layers.Flatten()(model.output)
#x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(256, activation='relu')(x)
output = tf.keras.layers.Dense(11, activation='softmax')(x)
model = tf.keras.Model(inputs=model.input, outputs=output)

# %%
model.compile(optimizer='adam', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history =model.fit(
    train_dataset, # Your training data
    validation_data=val_dataset, # Your validation data
    epochs=10, # Number of epochs
    batch_size=32 # Batch size
)
# Out:
# Epoch 1/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 3427s 15s/step - accuracy: 0.3777 - loss: 6.0190 - val_accuracy: 0.3099 - val_loss: 31.7158
# Epoch 2/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 3470s 16s/step - accuracy: 0.6313 - loss: 1.1330 - val_accuracy: 0.6567 - val_loss: 1.0813
# Epoch 3/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 3197s 14s/step - accuracy: 0.7058 - loss: 0.8802 - val_accuracy: 0.6589 - val_loss: 1.2910
# Epoch 4/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 3204s 14s/step - accuracy: 0.7496 - loss: 0.7480 - val_accuracy: 0.6788 - val_loss: 1.1081
# Epoch 5/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 3233s 15s/step - accuracy: 0.7952 - loss: 0.6230 - val_accuracy: 0.4640 - val_loss: 29.5601
# Epoch 6/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 3218s 15s/step - accuracy: 0.8122 - loss: 0.6280 - val_accuracy: 0.7122 - val_loss: 1.0192
# Epoch 7/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 3210s 15s/step - accuracy: 0.8402 - loss: 0.4990 - val_accuracy: 0.6125 - val_loss: 1.7645
# Epoch 8/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 3313s 15s/step - accuracy: 0.8144 - loss: 0.6177 - val_accuracy: 0.6686 - val_loss: 1.1445
# Epoch 9/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2951s 13s/step - accuracy: 0.8426 - loss: 0.5078 - val_accuracy: 0.6499 - val_loss: 1.8115
# Epoch 10/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 2706s 12s/step - accuracy: 0.8742 - loss: 0.3970 - val_accuracy: 0.6595 - val_loss: 1.2472

# %%
# Preprocessing step
# TODO

# %%
predictions = model.predict(test_dataset)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 98s 3s/step

# %%
predicted_indices = np.argmax(predictions, axis=1)
predicted_labels = [class_names[idx] for idx in predicted_indices]

# %%
image_names
# Out:
# ['-56lhw2AKjYI0Hnt',
#  '-6OdHXCBItIArPyk',
#  '-7241lsvPiVpNVFV',
#  '-8-0wltLEZBDTM5M',
#  '-GcrzANWUmrjk2tb',
#  '-H3eW6fAmjabFQEv',
#  '-HiiXK6MB6F1u40a',
#  '-K5ftb4XBgVegcq7',
#  '-PVsEsjibQBimlP0',
#  '-Q0Yo_MTjnhzgtN9',
#  '-TBD4tIe-a5UP1mh',
#  '-Tktdo4X5LgUMvSw',
#  '-U9lVuyU3rjePU2w',
#  '-dDdmvuCoHRNvJK-',
#  '-ga31aOTDSPAk8W0',
#  '-jatHKBptixJPEQT',
#  '-o4zntf0z1Eu0IJ6',
#  '-oeDjNxexoilWeox',
#  '-u1wASthhxChx3G5',
#  '-vCVFJtJTs7YChq5',
#  '-xAm9bKdi9qTCCra',
#  '-xq0ILJth3DVCYt2',
#  '-zJwe8YBxr85Kqg9',
#  '02OB8CEAAq0oyBwZ',
#  '02VCtYpDEvYkINWl',
#  '03DAx7-4cWGuhEX5',
#  '03xupnFJ2o_2kqKa',
#  '0BgZnLHZLYz1FmtI',
#  '0E9rEioGHMxjdCWj',
#  '0EWPPBjWdTUI9GOE',
#  '0Ec2a9JMPyN8E691',
#  '0GhwqifywrmSbfZK',
#  '0KbUyXdr0ZMjaFFm',
#  '0L0u1A_aWPUVG5aH',
#  '0RJ3OX2VBHElngIk',
#  '0VAS0qijlcyjfSfW',
#  '0Z5yioYpOoNH-iRv',
#  '0jbb92ze77YgRYK7',
#  '0r-YN2GLC7NQQcGp',
#  '0ull0MeSHKGf3pJF',
#  '0umwxpjgv3xtrzyJ',
#  '0wyzNFWaH6guStX-',
#  '0xg_-CaB8YpE3LBT',
#  '0xthRPq5IQSSb0Xh',
#  '0yyLOJ-IjDC9fv90',
#  '1FRKnFTejuYLMB4w',
#  '1G0SAiYEaHRA1ZRk',
#  '1NlN_OKl40FQC3Pz',
#  '1_b3eGKt9rlVkfQt',
#  '1b6QC4gxRbieTrPC',
#  '1bHZuYTRaquFU35l',
#  '1bt2SzdBV4Sv9Fyz',
#  '1esCtoEr2qlBQxMw',
#  '1g7BfURN3jfztN-Q',
#  '1hcP_Onwgxbq8uyP',
#  '1ojSz6gySxug4DHp',
#  '1pEVArPfN1QvPqSk',
#  '1pH-N16EKKs-iYcU',
#  '1q4rveLPqBEgRgLs',
#  '1qRddJ0MKyR7dmAh',
#  '1sLiR9Y3KXzWX0Dg',
#  '1wQICTAoPSpMCs-r',
#  '1xw7gAZfNRorjXYp',
#  '21CX7zTOyJfO_tge',
#  '21bGzJQLeUfS43UE',
#  '27Tn5EuM6Gss3i6C',
#  '2CV-yQaTTcCpQGgL',
#  '2E3LUx7GEuf5jVUh',
#  '2Exudd9ynuP4SjE5',
#  '2Hl6-HEB-jax97oz',
#  '2IO65ZMkvcDhimof',
#  '2LXcxOeQF5loaMKU',
#  '2Mb1DVI3h1BTo7y0',
#  '2OQfu4AWBw1Q-S6X',
#  '2SNqYgD0XFkddQ5g',
#  '2TtoRZPDc1PGpAZl',
#  '2Y589tmFGPZ9CWay',
#  '2YMFioSZH8uJs32R',
#  '2ar95iikaE408UXR',
#  '2oVaKd7pj74DAArM',
#  '2voJsOvAEo_ohvR9',
#  '2zVBXudf8S72u94A',
#  '33XWF2uMPSW-3ds6',
#  '350o3r_cOWzvejNx',
#  '35ueVoKg3ZfZPis4',
#  '37jG7gFwZ8dTCq5J',
#  '380NqFnHx5F0pAIY',
#  '38gRTJ9AXPVw5gO_',
#  '39J6ok1q_S9plAJG',
#  '3Di2IQCZwBoPc8Vg',
#  '3H2nM8mAeWEuZpNl',
#  '3HEl8rZKMWfuM9Z7',
#  '3OCn9BBLvFQvI7e1',
#  '3O_Du8fmtfLqkPqR',
#  '3SKpchskm2eaZjzj',
#  '3YRnxcaPs4XGPPV6',
#  '3jRFhsjPnpJ0CZ11',
#  '3kU1lE-OpOrG09WS',
#  '3ltPfUmJFLRfymgR',
#  '3mrFx34SnbRqUo41',
#  '3n46pQQPTjRRfMkI',
#  '3tCT1dXLHivVYMhz',
#  '3tmAt4tvLdjBBD-I',
#  '4-gkGuKr7F2x-geV',
#  '4623DcIlkPhWNzCk',
#  '4BwPqaSGTYcnGZx5',
#  '4EI6E7xXXSnoTfwG',
#  '4HpitTseds6ei5Lu',
#  '4IWNLjibX7JUQwBx',
#  '4JN4WVIf01yRz4gZ',
#  '4MIIqUfR5VJaAfRX',
#  '4OPOjWN2qgYHgxB7',
#  '4PQC9Latb6LZxzuH',
#  '4QrgtEUQLn9D9Nbe',
#  '4USz4lnpBlJTpEX9',
#  '4XIHJrwejdi9xu6v',
#  '4ZPHQVkTnMXVKiRx',
#  '4aDfi6t7JYBJCAUO',
#  '4eRGjKhV68DAMb64',
#  '4fKZcxZH50VaI1pW',
#  '4kSy7shZ74sOlISX',
#  '4lCfEzcd_9PBtGMG',
#  '4wYTQPjehHFzenAb',
#  '55rv97OzpiiLrNh9',
#  '5AHvsAYlFCaEzJ_d',
#  '5B34C1TBGy2OID75',
#  '5FXNiTxbmLnkF-Il',
#  '5Fo7sANLPtycKigY',
#  '5KFlpVn93HU8F0m-',
#  '5PzSYcls4aLTCpFi',
#  '5YbMUSClF8-qG4UM',
#  '5_LFBBZChdeRx8Jt',
#  '5ibeXdI0_Cyfi6ba',
#  '5nq4AvGUMAfjCte1',
#  '5oybP1-Tvcdg0siH',
#  '5p2RFwdzV9YEES-i',
#  '6-h4SLZh27fVfpSR',
#  '627wbXsFizcjISB5',
#  '6ALTpgZ3A_37BsQL',
#  '6CriuPrkDM7-Kuzy',
#  '6DKd9oweg1l9yYYr',
#  '6ORxI1IO7tnWkqWI',
#  '6PAVSkZCaIwP1hhu',
#  '6Q98YXGRLxsi-nJS',
#  '6VaxrQNuRQoE_4OZ',
#  '6bZaPpg6FTXLSLAh',
#  '6g343d9_WbJW5bYN',
#  '6h-jiHLqmlrlTXZx',
#  '6kj76RY8N1B_Ps4l',
#  '6nMHUT9WtOtejPIS',
#  '6o58lIz7ialdNGuv',
#  '6qhTDhqxlso5JhSd',
#  '6rIxNAUFw93W8ZlT',
#  '6tmKD0dWyAuelc3s',
#  '6uchZQckxU45gdZx',
#  '6ynfqdiRluOVhiql',
#  '7-Y4XyaUtH9Yl8wH',
#  '75I-EqVOhy8DIsuD',
#  '79GTqQfijUkchxGS',
#  '7DjFJtmv-8a-PxUT',
#  '7J_2w0luKdWB1WUt',
#  '7WgkG_h4CEpFAEeV',
#  '7cQ3whVyNy8y4rWd',
#  '7e_vd051sCxtjur2',
#  '7edpy0rbXLrL9k6P',
#  '7gSr69PUyL2k871d',
#  '7ggtVkdUO2Z0Erhr',
#  '7im9mKkUm-pMh_gw',
#  '7p4Qy2XNlHjkQCYU',
#  '7rDfL-487RQTrMfY',
#  '7udUn9y4hGL4pr3u',
#  '7w_OYQHBroD4aZeu',
#  '8491BdlDcF27Stan',
#  '8CDsdSTxPm-oNA3H',
#  '8DAq4SiF0KZVW7PU',
#  '8NoGe49nKzWHQSNX',
#  '8PbYtOE_5ny-LAO-',
#  '8UdXVWWqvsAswLH-',
#  '8VOwS-q25wVfF4-G',
#  '8Y4LI7b5p86E23Ny',
#  '8YgkAM6GoMLRhxkl',
#  '8ckHHc4SArANwfDH',
#  '8eAlCQzM2hTKsMaP',
#  '8kJyI1i47Z4gcGiY',
#  '8lOVD83jsC0S8h2I',
#  '8qOS4e9AVMkJUs4f',
#  '8zKuLvMrfrhGOEb9',
#  '926Gm4ehygOQkQZH',
#  '94oW-L7GR7PIUD-Z',
#  '95BseBGsKuYuBmVa',
#  '96q-c7zL8sLbyU3g',
#  '980kdZQWD5xRF6rS',
#  '9CgeoBvgWM9ryMR5',
#  '9Lg-EJA2XdzoI6kJ',
#  '9X5XBnNN3_2gGKI1',
#  '9cTQUU-RMAu2L2F8',
#  '9cna8euwRfLWF5gP',
#  '9e4TJPEcSBoTkzYc',
#  '9fH2cDRbSf4hajxT',
#  '9lV4ogjliSpOoY1H',
#  '9nQmzBJwvFZeG4_P',
#  '9o4YbecojZ4Agvv1',
#  '9qvi3uZ6KrZyQMl3',
#  '9v7eXTyFSiktKsEP',
#  '9vhkxvr_rZbsqtbr',
#  'A2kK5SbbLPanWxA5',
#  'A3q4PVimJJ3dnF_W',
#  'A4uIzYujNM9yYz1x',
#  'AErWeja3C49Uhx0z',
#  'AHbwcvNx8lt8Kv5M',
#  'AKgym3dUHoyW20xW',
#  'ANARVuI9Py_n46DF',
#  'ANkQCEIW822cKd0c',
#  'ANlT6YABgQuvbDN-',
#  'AOFdcDe05AQyDill',
#  'AR2HXO1lt0IoCgnW',
#  'ARM0qzZLGjKKZC-F',
#  'AY1i0nDWZPq-oVHK',
#  'Ac-Yd275YcoP2hb5',
#  'Ahmb1XkT24WEi8yN',
#  'AiMpFTxuRUTosgTz',
#  'AimyrnebZ7V7VRBe',
#  'ApOuZhlWB32wMW57',
#  'AsRsz4jLGsQ-ZW1n',
#  'Ay3UbF83o4MeflZ9',
#  'B2n4o-LUTgRAFED9',
#  'BOYXsFtw67OJl9AB',
#  'BWQ0rmKbihUh6sxR',
#  'BdokBH4XYYXEktJI',
#  'Be7wVvq2LM1smzNM',
#  'BipjIVf5zD_Ccf0l',
#  'Bj6vta0D4JZqCCuP',
#  'BkWYGSk6Dz8cW9mX',
#  'BoX3Dwprb6qn8nFn',
#  'BouoJYGHhqLZdGA4',
#  'Bq_EuhXfM37xsatp',
#  'BrKLsP6MiFOoxnQK',
#  'Bsan0ccI_byoRjOo',
#  'Bt0JQkoFceGcmdRD',
#  'BtXWHd2tJOhb-DH4',
#  'ByVUwbPvmxsTPn8d',
#  'C4eFR4FVG6tuXQF8',
#  'CBCtLFwtpKspbtAm',
#  'CISwPOvv8SLLhW6P',
#  'CR_92lFNI59-XEo_',
#  'CXjwImFaVvfSKcmO',
#  'Cd_5uLOVim1gb8vJ',
#  'CjyoRLtC9sW4mLsf',
#  'CkK4Z0mXTU7zfVP8',
#  'Cn0wmGdJ5NZ7jLAB',
#  'CotPA7gJ1rlSWcCr',
#  'CqSON78MpqWtH3Ne',
#  'Cwioc7xOMPuCYrFq',
#  'CyLfvCs7RsAsNFeJ',
#  'D2j375h6pyVI1MdK',
#  'D3YaGTUq0cBLW22N',
#  'D6jb2EY4NdMn5vio',
#  'DA1wd98PKZbAUBxQ',
#  'DBJGJacKfMxjSwGS',
#  'DF6Z0DXQ5zOsFXLm',
#  'DFG29jW1TZ6tRAUo',
#  'DGaJ7t5uxQp-9qJd',
#  'DHTH9fypFYrMNSfd',
#  'DMuAZiWMJq96RE59',
#  'DNAD3Iu54aIdOQN2',
#  'DNJSHPBVBRxYlgT2',
#  'DNmjPbihpV1drE3L',
#  'DOkXFAr5z-62cZtz',
#  'DZ8tWlTzDSPIxlv0',
#  'Dl6dUA_P72iaV_Gk',
#  'DmZ-VcA9ZZYxm8zj',
#  'DryYrEKg9Ty0Bgb4',
#  'DstUfi-DLRRbrP3B',
#  'DtLODVkRoQKRg0O1',
#  'DuG437zzWhxT4F1C',
#  'DuuQIrqQHbK1Rzo7',
#  'DwGQuHf_CUvfnytX',
#  'E94WHDtREg_4UKx0',
#  'EDCt8y5vsVRL3lLB',
#  'EGauwIJ15F2VIQtO',
#  'EIXV8lsNugbXnuNh',
#  'EM9_I3yFs1iSgbDl',
#  'ETa1lqhM-2SA6JDI',
#  'EbKt1UMo0q2KNSMQ',
#  'EcTDPh5m43PspXm1',
#  'Ecshom3CCxgqMvWn',
#  'Edn95JAgP_say1sJ',
#  'EiUXMfXaWDkHTDgy',
#  'EnLcWfGttS1qtadr',
#  'EpQZ3frs6Uu6f0a0',
#  'EpSMyKQzHvBgobkE',
#  'Ew_VFXN1-fpyXy0m',
#  'F1FH7jMDGjGK_LYy',
#  'F6ulKoGxnp97ms9A',
#  'F8q1MSFCfo17_pFq',
#  'F9u5wOsKPxsfqx01',
#  'FB0MQJUlljHnQMbI',
#  'FCKViAr_j2bGNad-',
#  'FEdO1zGd78FI64_0',
#  'FFgpeaXufRHDg6EV',
#  'FSfoLOKV0gAcKjc4',
#  'FWQTPQoCGtlG6WOc',
#  'FX8HuVL-tPG8WQwz',
#  'FZgM49xig56LsNO4',
#  'FfojmXjNzIO3LlqK',
#  'FhgsCcPz6nUVOIga',
#  'FiI8oTUE_PLwfuTe',
#  'FiYIazKwoYvhP0RG',
#  'FmTxV2zxW9A_QOJx',
#  'FmWnvnYfagNgJyS-',
#  'FpdW4axUm7rTvvGp',
#  'Fy7RtntM4Ynl_n1-',
#  'G4YA8kYlU65kXLkf',
#  'G5gFrVCNgEPQ5KGr',
#  'G6jXcy9Dej0YLw3O',
#  'G956mLo7WkUsKXVK',
#  'GEcGAlbSdD0UoBDO',
#  'GFQ28Uo-SZVE_ZNV',
#  'GHJq6QDSfHmsCdkE',
#  'GNea0QBvf-7iRjCV',
#  'GPy_MpIHGOtAvTvA',
#  'GVA35YnRcS6PAJj6',
#  'G_EXYAaGLqPtcJF6',
#  'GeFEXm--sdo40hVC',
#  'Gky5pvr5C5pSMU-K',
#  'GnL94XPPwqljHu1f',
#  'GrdIVxJ6i9boTli-',
#  'GyrO0c-efCuNcLZU',
#  'H-7R7b1tJaTNZR2t',
#  'H4DbP_RRNnYCJqNu',
#  'H5qh4ILVheKeQTrc',
#  'HCdbMZI-FxewLSsm',
#  'HD3EIvOX5kIs1PHR',
#  'HDZyPkZYXiFfzGYc',
#  'HDqlNzKFk37cI5eL',
#  'HJM7tcM3BHjMvffl',
#  'HJxxeCjXPBuP_qVt',
#  'HKPd2YBKSbPBpYrv',
#  'HNvGp_lo0CLvRjwl',
#  'HO6W1Aug4gvjKBtD',
#  'HOa3aA84aJqJQOZe',
#  'HPSziRfdg9vO0rGE',
#  'HZ9wS0DDREpZqDKg',
#  'HZTJFrqEUYVTWsn7',
#  'HZYDZ_wOO7P-8ur0',
#  'HeHym9Lo6KWp37WH',
#  'Hf_VOJNtW4lX5FS2',
#  'Hftb2e2ndbj7Jp1k',
#  'HgyAUi75nzCR-e_Z',
#  'HqvUVlQzW0He2e4P',
#  'HrFAYUX-NSeeN9s6',
#  'HuMcd1nIfFMo_l0x',
#  'I0bpbYtAEz-StIQ4',
#  'I1sgtftgVw_aPs9L',
#  'I6FstGt0E811A_Z8',
#  'I7xm2HCcb5UDi4Z2',
#  'I8cEz9UC7Hxl1xCa',
#  'IBdi_Sq0AOvnasIm',
#  'ICp6zDvkyCn6i3Ft',
#  'IERLR88RDdUWA_xh',
#  'IINv9DBw2c21YTuw',
#  'IKVSZHhMm-jKgSrq',
#  'IQKXMoZQJX4-eMts',
#  'IQT910n-qZo410_v',
#  'IQvqEQi46_dh_WAj',
#  'ITGMBMOLPOF-Mjy4',
#  'IVgr55IuLnywnYHt',
#  'IYBkl0VTknw42B1N',
#  'I_qNyCh_b5G-NISX',
#  'IfzfVRA4Pj6HEB88',
#  'Ik17LHLFmmvPBUi1',
#  'IkOP0vRUXQ6DaNRB',
#  'InDPY7S2EuzO51Bm',
#  'Iy9-4TXwz5celvQw',
#  'J-MRBc5e5VQAe9Ct',
#  'J33ovOgW0PaDpz7W',
#  'J8w2Sua5wQh2hQt7',
#  'JCbvoazEd5yohc3v',
#  'JH9OYupOfjxZpUoN',
#  'JIk44tGexR_q-FZ6',
#  'JJ2ogtwCNWLqS1uI',
#  'JQx1PnnXs4bNIBdA',
#  'JSCLR3wxwAwfiz_a',
#  'JUd8IiDAxpgDSRiN',
#  'JYuM4XgsCj2I6qSW',
#  'Jb-S1qWsggvkbWUR',
#  'JeUP7s3k6RX1Y7Ix',
#  'Jf1pMZAj9tVWEoVg',
#  'JgL3Lxvnq5HPlye2',
#  'JkYUbpJrg65AAX2u',
#  'JlnAxatfUVo5ep4k',
#  'Jqz0QhhpeCeDK9lV',
#  'JxBgb05DE2zGdWhg',
#  'JxMyoKmynYgMf31m',
#  'K-zq9vVaKtN9XHPP',
#  'K4gYBTamBWSk8K5p',
#  'K7B7xTBjU4jOK6Zi',
#  'K9cPClfy245mbvZd',
#  'KB0h7f0DGSXuIBoV',
#  'KBET8hYJnU84DTh_',
#  'KIvtjWVHffZ4iuAf',
#  'KKobjYlZw8n_OOnu',
#  'KNbgeSPRcwDmMzdM',
#  'KQeNtBjtw_jzepQR',
#  'KRIAkvOeKW-urW5O',
#  'KS714PtfSYf7cgI3',
#  'KX77Hi6ZECJTrxiU',
#  'KaUTU-3IMwzGRqtz',
#  'Kal7ke327u_dgbIW',
#  'KbDvj-Qf7dXt543K',
#  'KknJEp_uNXapiuO-',
#  'KodKMLklKAYgvRKv',
#  'KsHw1sIZ4aLLhjae',
#  'KsZDeSIe6ysaIbYO',
#  'KuZBRfx8EGIA452d',
#  'Kw3Nvz53ijsd07XQ',
#  'Kw6Rm39RXWDNDupJ',
#  'L1FuIXyvAEGr6YC8',
#  'L1fc2XMsdVqKspsd',
#  'L2NjaL2n_VOYm-cQ',
#  'L4530sbw918whVQK',
#  'L6R-AXsc06vEmPcl',
#  'L6_lCUHVSfeOOWW6',
#  'LE4jzOzV0jEehCpP',
#  'LJ3EqcwZI81f02Sh',
#  'LKl33GM1f7B5U3LA',
#  'LNTKJY447y-eJj1g',
#  'LPs1PogzU0EftGn2',
#  'LS6Pg_1CVqSQ6hyl',
#  'LiRKvKHJuf0LT1Eb',
#  'LiXF08cvIORuIHzq',
#  'LivY_00dlfzgUujE',
#  'LkYbitBJQ-EHLbBq',
#  'LlN4kf45g13uqojV',
#  'LnuYCfl4OtK1Zerp',
#  'M3cGWXMROdcFOYkw',
#  'MBmCnhomhvMMIG7D',
#  'MIYbj9m4Mus7TDBr',
#  'MOHBuoOTK1UzbpJi',
#  'MOddGeJtjSewK7Nd',
#  'MXIgGTp7i7p1qRTK',
#  'M_Azda3NzS9SV-WU',
#  'MdD58XjqvLyqsw8-',
#  'Mpz0XiH0pic9tfx9',
#  'Mq1mxP_KTwuzdQu4',
#  'MqbYBh84jd1ikM6w',
#  'Mqq2A2To-qhfMUXo',
#  'MrWLH33aC-XA_za8',
#  'MurCBDLchmWRZySc',
#  'Mx2Cvxfc8yqxjLoh',
#  'MyjhifuP-JzQA1eA',
#  'NBQNoxISXnOxz8Xf',
#  'NG_vjb7kXtjjTAV_',
#  'NRjzSMSJxkKRwaj3',
#  'NTuE_AlK61gE_BJX',
#  'NXI54blyfgF-_iPn',
#  'NfJIk8eN3KzXgPrF',
#  'Nwlv7GSjNoS5EwDc',
#  'Nwy4-Dqc8kLBh_RP',
#  'O-BK_nIkuqIGtiap',
#  'O-EhJSPYkL8031pf',
#  'O1Q-tou5LLPLVFEn',
#  'O52XBgeuiZuJnt_c',
#  'O9-aNDUp3Rj_wNXu',
#  'OAa2qOwqWbChVCXK',
#  'OEqBoN6-79SPo7uO',
#  'OF3V2eYCyJYxSX8y',
#  'OMDLMkqFe6C4J7fy',
#  'ONMX-uxRqvrGWyzK',
#  'OP6V8U24DAn9lWKi',
#  'OPClMdy5yCx1Hbi7',
#  'OPxcsFZmUlTHYN4J',
#  'OQWQIgA3OSGRpJNv',
#  'ORHbGpCerG3KIMTl',
#  'ObRW7hvb47EJS2SV',
#  'Od8gCAgSlIj9nNbO',
#  'OenHbnQPLAlJbJqY',
#  'OlQdnHqoWB1HXTGv',
#  'Os6-8yjTA1UZZTJ6',
#  'Ou-LBqELX6-_qBBL',
#  'Owi2C-zcHKG-fr_H',
#  'P2RxXhKyRf7Fm4Nf',
#  'P5htnkQaDlVrWSxR',
#  'P6P7TvcxIXxZMKV6',
#  'P7Om9AYiYQEMP2UZ',
#  'PADRX1wKwb_U5hcs',
#  'PBK6185UKs_qUte1',
#  'PBr94wIMtCjV8FiN',
#  'PBtrhSvv8FtzjMLV',
#  'PE7lfMOg-4E09VDE',
#  'PFRZtGExjdeAavL_',
#  'PHE-ZjPb0h3KjtYt',
#  'PLnQH952QtQbtLsm',
#  'PLsnskfYHuTekHZG',
#  'PS1x7c8jolhVU01A',
#  'PT1ZJTvAzw79T_dY',
#  'PU0EtVbKwqPqKCl-',
#  'PV-pClMVmqojMM61',
#  'PkSr_jzMJtBQyxDQ',
#  'Pm8LlbQ2rhRDxpAv',
#  'Po4NCiuK7w_TIZG-',
#  'PrHz0HwUMs97lKj6',
#  'PwDYuW-MH-vVG6tx',
#  'PzaYCJejrEInmIPW',
#  'Pziu4C04oi28-kQ9',
#  'Q12XebzZtgwmdRLz',
#  'Q5HZTMOlI1eUf-bx',
#  'QETrWUxyrlcgG8T9',
#  'QIIOufzLjdpA3p-h',
#  'QPV2st2AWMrfASgU',
#  'Q_iFzrdqy-BOImvU',
#  'QgsXGMpWq3khad9R',
#  'Qkl1LpRNN_NefSdP',
#  'RBx31kiDT9v5mhRa',
#  'RHyc47MvcEfxJaIj',
#  'RIsboCBXBWOwsu6S',
#  'RPLw3khplw1Vo_tE',
#  'RQuqZWIdjTro5xoS',
#  'RRKtSnKIqtUPbBd1',
#  'RW_TSPCuup237Bb2',
#  'RZHH9mMZD38qUCzS',
#  'R_i2JNJO51osiv2q',
#  'RaFol46w1nJe_kov',
#  'ReRAJ0ZlxW2LLgm3',
#  'Rf8t48Ot_xcZr-0N',
#  'RjfeqgwInHFviUFh',
#  'RlP7hro6BlcW4rTJ',
#  'RoRxQoRnW-3MJZ-P',
#  'Ru1J-IiU_i5W6uDe',
#  'RvPnN3sZ5TyVRW8g',
#  'RziQEO-CPgwTtMo1',
#  'S0wTaqYf15_-cQAQ',
#  'S1-nbmcLR1R0P1Jh',
#  'S8363VsH7l51u0JW',
#  'S8NZJaAUc9NiUKnj',
#  'S8iueyk7PktK6ed_',
#  'S9VhD-NT2S1hPswD',
#  'SFIMYz1cqJEbyMGE',
#  'SHP0n86wP_-jHa8P',
#  'SHeGgMFvb4g87PFC',
#  'SP2fGdFcw3LQLV_P',
#  'STWrkLEKX0hjrkRk',
#  'STcBEAjaJEXFL-n_',
#  'SdoYx154-qWqOmce',
#  'SeJwyGwOSx9HAA3M',
#  'ShI9iP5Hcq8iQZHc',
#  'SikkNTkOxbFXW8__',
#  'Sj1a0pgAovl6BuCa',
#  'Sm1_8r0k7M3rxF-8',
#  'SnxM06sxIt0v83TL',
#  'Sw8B8sN_cth4RSYg',
#  'SwR5bJddkwEyvnAg',
#  'T33J7H9TdmTR85zP',
#  'T8xBLJAQ7UdbCDnq',
#  'TCAKc-IJT64-5foa',
#  'TE-DKUhoqidwGEUn',
#  'TFdFuh5Wtp80FlG8',
#  'TGjpR4vmJOdEK80Q',
#  'TJ5u75_kHoWHBvur',
#  'TJwJPXiU4gkIVdWf',
#  'TK4nargLXMpDZF94',
#  'TKJ8N9p22i7GNi5m',
#  'TLEUdz0hzz31L29f',
#  'TM5yCitnoNI0oCPr',
#  'TRB2-4c7aF_vsJ6N',
#  'TSPGOEdItgDmUHx6',
#  'TgZ0-IbnxHwAhhls',
#  'TgrRED38ttQtUAan',
#  'Tie4pCtdHYIiZi1r',
#  'TiuWnqgt2CvHFFhJ',
#  'Tj_RcEcJPTGSOxBo',
#  'Tk8z9x8auXYPn2BM',
#  'TkjZ8H-0e-FdSJlc',
#  'Tm6Hn7iR3Wjg7tt_',
#  'TrT5pFQ1DnsyWpff',
#  'Ty829M-Znv_sssa6',
#  'U4glu4-woAqyVjbT',
#  'U7qhu4k7AL_YI7Tq',
#  'U8YrcltM0XtjE9zf',
#  'U8_5TQEjPrbMKnbT',
#  'U8qLDx94zVkD0Tpv',
#  'UHBqEzoMxq4iOxG5',
#  'UJKD2orDb8NszHj6',
#  'UQ2wS1PLYGtWua9Y',
#  'US0WJLDat9iKEZSt',
#  'UUcyqkNo_HM-ebWC',
#  'Ud5dD3kO-4cvU63l',
#  'Uh3K8IJ7jOaUBOnn',
#  'UiF3DWjhO874WeUZ',
#  'UitK8Bv_7-82mXW9',
#  'Um9yLl07K0m9VKDH',
#  'Up8V7gDbLdQAftnL',
#  'V1b_fTkscLmdC5fm',
#  'V4FZQe-av52h6r36',
#  'V8LtFKuhxO2R2xQV',
#  'VAwZfn-zWA24rKDO',
#  'VBHmezUHUSzaiWCg',
#  'VMbGXaTIeyEij48h',
#  'VODvvMnkm1uQQZxL',
#  'VPbTPBr1CwC3UEwD',
#  'VVBR9uONcW3hxuVf',
#  'VVVEDQRhhPz2860r',
#  'VYcBYxPHBp6lYyP4',
#  'VZFbeyxPwe_yViPW',
#  'VZVbQ0RFtN7bROZX',
#  'VZgsVTsNPERD64d0',
#  'VbcTerWAiecU-_T5',
#  'VcdD-YWfLw-EKRP3',
#  'Vhdd3_zb0x11aZYh',
#  'VlKdd1eUZ5AEatmm',
#  'Vm-h4P2PQJV15vPW',
#  'VnOMWUc72TX9z5h-',
#  'VrBfBAIWp6WFJT7-',
#  'VrWC9y46bFXV-mzS',
#  'VrcewP8zC-loLPJ0',
#  'VuM1Bh6cjTQl60u-',
#  'VxZa9MutAOUc5zvc',
#  'VzoQaO-_7DZHdQ-o',
#  'W72PD6YAcouB-FiL',
#  'WE23pC0zk73JN07W',
#  'WFgph1pN8UahquY-',
#  'WGcnmtvUrXzMbkns',
#  'WHGlrlBuAUAuTng4',
#  'WOh_n4oB_wubjlW8',
#  'WSAuWYS0XgwjBhbB',
#  'WTRQ7oLsXbkaq33M',
#  'WVCXBERw6a9b6Q5G',
#  'WVGcjDpW2TON0ZZo',
#  'WfoB2I6tgIB8e3j8',
#  'WgXMyPXOcHO09hzo',
#  'Wkf66W7HTyTSJove',
#  'WnBfoqZVMzOOr_bk',
#  'Wq8diDtBqWfuVNeG',
#  'WtB9uciQZvFdfLRI',
#  'X1BNRo6JevZnPXAJ',
#  'X2FG6CyQQk6oftMI',
#  'X2f44zJsoiFXBnJX',
#  'X3WEspkGdJVAMBKq',
#  'X6C_LM_cpryt5nNd',
#  'X6wq174aw9BmI2SQ',
#  'X8wXu8AqxMPXBy-y',
#  'XAJsLkUzSaYW5g4n',
#  'XAPrsL-d-F2c17Sa',
#  'XAuCdsmCyucewD3m',
#  'XBH3yKbU_jAIVZF1',
#  'XD4ImTdc7O3__7zn',
#  'XHOLg02yITULLjiY',
#  'XMdt6Ijf0M5DFBOm',
#  'XMe9zNbPW6pR_pDN',
#  'XMzgeoHxZ0O8Oqec',
#  'XNpEa7TcEEuzutsi',
#  'XO4WRpylRilw6xmB',
#  'XTVQW3n29Snx_Vim',
#  'XUBWx5t5bWSp7jZT',
#  'XVuUX_8JXbJki2A2',
#  'XZxXEnpHGNKd7Pl6',
#  'XjknCRHoUaihjA8M',
#  'XlysiFNkOvyooI4L',
#  'XmBFnq-HsNw8TaGh',
#  'Xw8PMrBRWu-YzkS_',
#  'XyxOwyfX3LYAluoa',
#  'XzAw22prrpETudgg',
#  'Y-US858g5BH1mXMo',
#  'Y3wq-Lx75bO_987A',
#  'Y4bmKMgtWyTpaehI',
#  'Y6RabkpuTC-eNL4j',
#  'YAdlfMsCUe3w5l6Y',
#  'YB7WU1m-kmDfhjrg',
#  'YBBD3k33YPQsUH5E',
#  'YBa48SccnEnLeJQT',
#  'YBdovNpgKmc08J_D',
#  'YH_dv-yZB5V6uQMZ',
#  'YLduUB9y1fOlVU71',
#  'YOewutgnKiBHRZZY',
#  'YSUpek2x2hMnaCM9',
#  'Yd3OX4adbFpYPRLX',
#  'YeecROr50l0eQt-K',
#  'YfDiAmnqvM-I3ZKq',
#  'YhS8lmqlwA9kf2TE',
#  'YhvuFNaZ9HKsrHRV',
#  'YsUW5vslxYTsHPcw',
#  'Z1-Lxtn08bhoqwCR',
#  'Z4CK3eZU0rpsAk8R',
#  'Z7uelPbw9UgdYjUn',
#  'Z9l-a5dsMn3873Uu',
#  'ZKTwUoZYvxtbAb_j',
#  'ZLnZ4eNyNsqibVtf',
#  'ZNBFMS2CV5K495l8',
#  'ZSQwF1Me-j5ZV_xL',
#  'ZTt0xOx48oLI_VEp',
#  'ZXrLU3okF1vwew2z',
#  'ZcYYFHwHwiBrCC89',
#  'Ze29sVAC_KGEUJTr',
#  'ZeE2Mv6WtokRebQp',
#  'ZfEJABLz81gEJZFL',
#  'ZiBKN7k9qgkz6CmA',
#  'Zllc49cjw1kCJDSB',
#  'ZmuY2cJEwrOjTSYH',
#  'ZnGd2r2hEVFMG-Bk',
#  'Zoj7yt6UdsOpukfS',
#  'ZqyzTOdr9uAGxuhU',
#  'Zr3a8yi9rAEUuGhr',
#  'ZrRbpcktuj9GWcIK',
#  'ZsP7dO1ZXae9vIkb',
#  'Ztq2OCiRKeqiW0cF',
#  'Zxsti3rf-tUeXFZ2',
#  '_-_K2eqZhHDOwZvh',
#  '_4IrR0yhl21gQJC_',
#  '_5YFxLhFwGYSIgsc',
#  '_6skJ-ev8mdRVvGB',
#  '_943MVifa3ars_IH',
#  '_EBUL7Spyo_V1jy1',
#  '_Hcb145r4APSCmQc',
#  '_MrqzvbI3-MGeKsd',
#  '_N-x7yIPgyWzJU2G',
#  '_QL6CiuXlIIb-JY2',
#  '_WajlMwUDtI3lsZS',
#  '_Xrx9f_4DZKreKSA',
#  '_e2mVi98Mcn9Vn9l',
#  '_eKDb1gw3WzE70mj',
#  '_eiZbeEPqC2MVHff',
#  '_jAG9GTzHxnUUi60',
#  '_quX9iNaxeDlgG71',
#  '_wrz8lr6uTXldAzh',
#  'a2-6Kx2APx9LetQG',
#  'a32cAtNzr4M-j8s2',
#  'a70IODXn9p1F_-n2',
#  'aBcDR-tXIGQ8KoGQ',
#  'aGBcax1l33c15uZP',
#  'aKMK_7dmFb9DjbY5',
#  'aKoXOOoNaXhG4WSj',
#  'aMKpGFE6QdAmQuHf',
#  'aNtYH-q_he2rYgqQ',
#  'aSuel9dbdVIfSC32',
#  'aU1gwjoz-WiHgm8N',
#  'aVzEkjO28rYHfOCV',
#  'aa8_Hh3jAu8EBnP6',
#  'aaGLoqAf8c419-KO',
#  'adVJJzrkhgxRvCSg',
#  'akVo4ymIVkxhZa8k',
#  'ar8b2a7kKNCOluzW',
#  'at0bcsBmmbc5ETLK',
#  'avn76kWZr1qLTEP5',
#  'b1zHYAw1c1-ac1IC',
#  'b5pHQ84NKTffMCPQ',
#  'b9btDG_EA5qFpnYj',
#  'bCU-9BhPB8iM-PTp',
#  'bEEMuhdWjLrV0ed4',
#  'bRgLHDmMAM5VprB7',
#  'bUgPq3yi__DQIM4P',
#  'bX0OLhDYhqRuNhFm',
#  'bYMWcWETne4kxkYh',
#  'bZwD8zUZ4GM-WRpo',
#  'bbXO-TCuSME42gWD',
#  'bhqQRaSmg_VAs_Il',
#  'bixEQqZqNXsYx9Ao',
#  'bkuSkFsVDBNPcHb2',
#  'blC3wcN23ENbkTDp',
#  'brm_rdPY1myLMAfe',
#  'bsnF7t72aVPEwp2W',
#  'bx1_wH9vFhqvQcV1',
#  'bxg8Zt-oGZsnneAm',
#  'byCNff2jRr5PwqPc',
#  'c3bDajyBbdMRMUxz',
#  'cDvaq48VqszcNORL',
#  'cE6WMpv0im6KGFaM',
#  'cO9-3epDeWkqCmUt',
#  'cTrm9LIeuzOpV26i',
#  'cVEfOHA6TBRkwaqD',
#  'cVnncGaXQqYAPchj',
#  'cXVBhsBaS9hYymZz',
#  'cYhK8AwDi1JBEL1q',
#  'cdQHHAGjCiefjmgl',
#  'cdxFr_oCh6akvhD7',
#  'ceLK05O6ijwYV1bV',
#  'ciWWzM7x-Aykcfyh',
#  'cjAOGXY-Dmif2zxy',
#  'clHC_kJrGbuebPWC',
#  'czx1KSd1l5gWTtw3',
#  'd2QfAVdtRHTgmvgx',
#  'd3PQyYrZ7rjPUwEq',
#  'd6B7auIGqaqkcUcT',
#  'd7KGsw5tgJtcJtyL',
#  'd9I-S4LprrdlidsU',
#  'dGZ2uA99tK9HbS_e',
#  'dICxk2RnbLig789P',
#  'dIbXW98MAkE1J9n1',
#  'dJYSzf3kCWqn3XuI',
#  'dQ2YNm3SkSg-1GMz',
#  'dS52D1B7bgjV_3D4',
#  'dUlAvnOJhTVSiEYF',
#  'dV32SyY2jduZNFsN',
#  'dVcbQ7QfhVgYed2V',
#  'd_cETczNPjSPfLAl',
#  'dawIjKI4aUPa9sIF',
#  'dfC0iEDHkgt8vcpR',
#  'djcamuifUHzWGChA',
#  'dl_J86axaELfdTKr',
#  'dmtYOAS4aQeAaJ1C',
#  'dobA1omUtPz0K1sd',
#  'dog5g8is9XWbWOVv',
#  'dvSG_52oN3DJu-ts',
#  'dyvHqst4XWp32xAz',
#  'dz6vI-cFBJxae0JE',
#  'e-bPwq_oHrxLc8_0',
#  'e2uRX2ku2YKOUX6A',
#  'eEJ2_FgI8KeP9MQ-',
#  'eHwxnEn9FqPT_8UC',
#  'eKIFdpuPWWbLLTrV',
#  'eL2f_9A4KHE0eInr',
#  'eN6olfwO0xoXM88a',
#  'ej5R6MSbhkTYPgbT',
#  'eo1qYOE4yMBs0Xws',
#  'epYXUX--3wJbp82x',
#  'es0yPv2cmWsWCMSE',
#  'es2XIP2ccHmkSvRQ',
#  'ewSs3XS-c3YzQ9CF',
#  'eyfOCwbdrZvkGTpa',
#  'ezq3lFXlc6s811Xk',
#  'f5jDNl6nuiFvujZy',
#  'fH5scO6-q_d2BM9F',
#  'fL1Hah8gKM7VtbwC',
#  'fPpmrkEJCpiICCOS',
#  'fz9DpEohmKPmYVNi',
#  'g0o_ZHqlvyJQu6sw',
#  'g7CEv40pMDMKOiNb',
#  'gABGT1CoWD8CER4a',
#  'gAaWF9fQrP0w30Bm',
#  'gBMkEesrKZ1CWPR2',
#  'gCkCYLqmXvPaJe8i',
#  'gD1cZ4DxzTbIUfA_',
#  'gDNEilJat25x79y5',
#  'gEbe4a0ao-ut8nC5',
#  'gGDLejoVpSGX9hJ3',
#  'gHdJKoD0LdK0l1Q8',
#  'gKN29l6AcENpxLdn',
#  'gS3ZLbf2yRSmC5AE',
#  'gSlvDkV1qPy16_tO',
#  'gT5VQky6qwdeyTOs',
#  'gZK_vgNYF-X_PMyl',
#  'gb9MdCei75EcYp-t',
#  'gcMP5xJpxGzWy32F',
#  'gcPVRtzhvbo3CE-6',
#  'gf9J6KBZ93RPXoIq',
#  'giJ4T92mTGkLdBul',
#  'gjjp7UUF3Sn1pCKq',
#  'gqO4xVtp-a4in7Mn',
#  'gsSj-hoM4W9YVmsr',
#  'gvRgGKhT3X4NaIaO',
#  'gvvln0OIQgGamT2P',
#  'h0MkS8ictRE-qYCr',
#  'hEWHqSQL-O4YYCb9',
#  'hKLKV9v_IZuSov-P',
#  'hKUc-GDD134AmAUr',
#  'hWZN5vl_Y_c8nqGa',
#  'hXx535BVnPx5vIPw',
#  'hZuQK47sZvYDjoI5',
#  'hb4jg1RSse_3t3kU',
#  'hivAAcGProj-Kf59',
#  'hroXa7nYoElasU8X',
#  'hxkUYq1Y3GPz5HwP',
#  'hyudCSy8n6lvubGx',
#  'i0ELKUNiwHiallQG',
#  'i39xBp8eTpzh_S5R',
#  'i3cOs7pjXUxdqE0h',
#  'i3jCCygYc4SiipEf',
#  'i7KEpiRUSbsf-PO8',
#  'i7mHVw2AVgMHcjOr',
#  'i9mN00ODPA_6vwS3',
#  'iGpPTHFWFnfAgvGi',
#  'iJuvTGJjf1_S4WAV',
#  'iK-gbcFfVex89oBZ',
#  'iLeb0nSuYlm5SwJS',
#  'iMeEPgyLb-dOJRps',
#  'iPNgnDIwJmsKPTVI',
#  'iT0_5lP2HiAvmjBX',
#  'iUBylvH05TBCD-Pl',
#  'iWEAiMiGJnq_BJHZ',
#  'iXWRVPCoNKq56HeA',
#  'iZZ4sGt7iNkj0w_G',
#  'idUMZESXmE75l8Lp',
#  'idfp7natdejZVx_L',
#  'ihUBgkCEorEBWi0V',
#  'imHDFc9w2o-hsws4',
#  'in51JrYky2jW8-Si',
#  'iqUiwh_twmh48rVB',
#  'j0u8giLVqgGIfKcJ',
#  'j5JyyAvwBr2uWues',
#  'j6i8xE1cvcpfqevL',
#  'jAQGvL7r9Wi4mp7k',
#  'jDPKQkCbNRvDRQGT',
#  'jJ0GN18yZjjKc00-',
#  'jLP5RFmES80HnW3X',
#  'jUDhcx1LwKuJyjkm',
#  'jVcyrjfOIL01V_NX',
#  'j_ov3-BfKiIF-Odv',
#  'jcc8ZHFs11r9x6ev',
#  'jdlZXmSf3Bj7YrUX',
#  'jhy6C56SNOEd3B2d',
#  'jvRdmWcK7sjL0gT7',
#  'jz8wG4gotiG2P1t1',
#  'kAWhOMMDGZno1gKD',
#  'kCbW5yT4YwOjrz9Z',
#  'kGW49xTLTmAH7-dZ',
#  'kLSK0hTeo7Eios-l',
#  'kP1m6OfgxvqzP_jH',
#  'kRX3rKsX8tDjYY2_',
#  'kVBal-DyEbHtI2y7',
#  'kWbMUxGeQwUQndCp',
#  'kYyu6yuyDk7GxYfB',
#  'k_1Jpq7J3IdOfHWl',
#  'kcSw_pOBefUV8huz',
#  'kcchX_xctTciA38A',
#  'kmWRBkTlNoFIfUB5',
#  'knctHvqi8Bk1e2RT',
#  'koYyjY5JLKpsRnGe',
#  'ktXA0heFSXy1sTHQ',
#  'kuIsiy0ygleQ1_h_',
#  'kw_7vRHn6Mso0R5N',
#  'l-qX_MLDuHlR6NRE',
#  'l2yk5L_yIqD7ks59',
#  'l44TxUUj_s0pF3MJ',
#  'l9Bk5VXQmM8d26t3',
#  'l9d8ONvlW0IWj2Iz',
#  'lENUBBuzOk-2ytul',
#  'lMbT3BMbZSrboe2d',
#  'lNn04ALTGMHQrAzw',
#  'lTPnJaJP0_3IpRQ1',
#  'lXq8769zRWSaHwq1',
#  'lYOmpuqUI9MEKCw4',
#  'l_7yvVHmY_venrbd',
#  'lcQuJpLnai61obSk',
#  'lh1P5_mvsibO9vKZ',
#  'lhVjUZa3Ewl8cg5Q',
#  'lo7tegsQ5uuVJNuv',
#  'lovgPqTavpVaI-Cp',
#  'lqUe8_y45YVg7x9Z',
#  'lzpMi9u2-hK80Wwz',
#  'm0F2pe6AW0Lk6xpd',
#  'm0OJ95NJImCETPIA',
#  'm0YodyzUZ_FxXMNe',
#  'm2neIwIuNy_ue3nU',
#  'm4uis2bVeFOFE3tl',
#  'mAv3fcd_OXHLFI7V',
#  'mDuH45cwUTYpZPXq',
#  'mKVKnmiV29EndroL',
#  'mMOT6I86w5xv1lIv',
#  'mVoLD0Q7TNFcji8Y',
#  'mVr-EhdaDlS8cw1F',
#  'mXVCGhxFVFm3UQzM',
#  'mZ85OqnzeY3bElLC',
#  'mbB0GkwmYMFfELpN',
#  'mc4UFdKIAuzZQdGR',
#  'mcq-ee8CM7ysdryF',
#  'mjIUfbsl2fxQnApA',
#  'mm9bY2H6iGn-pTiE',
#  'mrjB1xj7-Ztlz4hu',
#  'msIeP9LJeUlejVN9',
#  'msf7r2SMbcfWQhH5',
#  'mtg-EF9GBDnUeKws',
#  'mxAyqDI78Sshe3nR',
#  'mxLcgCmWhcdESBjW',
#  'my8jjODNU-UZDn_m',
#  'n08fRXHtTSUsaal8',
#  'n2Hy6XY5dTyiLK_i',
#  'nBLqWe8OqQi_LsVf',
#  'nITVWpyeTVveHQ50',
#  'nIXcxGPVhxrA-UDu',
#  'nNDyAlROhT0ROePQ',
#  'nOV4-JklUvxd2zav',
#  'nP7BZdU8iYX1pSGp',
#  'nPaDFUdDhncqnkyW',
#  'nU8Lg88_z1TjpS0b',
#  'nXxymLiyMsz75st7',
#  'ndDHO9nrj2wucyec',
#  'nizhfa1ZCTVvOmsP',
#  'njUcRRtmO5dHdQTe',
#  'nmpTiijT1cnJXRSL',
#  'nq3P6g9WeRUmShaX',
#  'nqlwSrJ3HStZzYmW',
#  'ntL-gnmI0NCHl9Oc',
#  'nv1SGwWvRw9MJu2k',
#  'nws25twa280bgL3_',
#  'nx68Uii-bw8LNZAa',
#  'nySap6289i8P6vBb',
#  'o08idUAfuSEOo4UA',
#  'o12TMnXbEHffq95h',
#  'oA21flEivhSwJdnS',
#  'oB8MA-Y6-IsnrBA8',
#  'oHG8v8mNTR7xCwI_',
#  'oIGGo4fPfK5TYEpO',
#  'oOmM5Ad5l33A_ifr',
#  'oQeHlJXGGC98n7jb',
#  'oWxS8OqIlrK0I_46',
#  'o_2eM-ZMaHp-TikF',
#  'ofDBNlbHTD10Me6Q',
#  'ok0Q3X77GzRg7wU1',
#  'omecYj6yFieFlfIf',
#  'omg6pabR8T1_ew5X',
#  'onGf9nCIuJNyKknE',
#  ...]

# %%
submission = pd.DataFrame(columns=['image_name', 'cat_id'])
submission['image_name'] = image_names
submission['cat_id'] = predicted_labels

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در این پروژه کاملاً دست‌تان باز است تا ساختارهای دلخواه خود را پیاده و آزمایش کنید. می‌توانید یک شبکه‌ی عصبی کانولوشنی طراحی کنید و از تکنیک‌های رایج این نوع شبکه‌ها بهره ببرید تا به مدلی با عملکرد مناسب دست یابید، یا می‌توانید از یک شبکه‌ی پیش‌آموخته کمک گرفته و تصمیم بگیرید که چه لایه‌هایی را به آن اضافه کنید یا چه بخش‌هایی از آن را فریز کرده یا آموزش دهید. همچنین استفاده از تکنیک‌های دیگری که در فصل بهینه‌سازی و هایپرپارامتر آموخته‌اید را فراموش نکنید.
# </font>
# </p>

# %%
# Model design
# TODO

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌بینی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در فایل <code>torob_test.csv</code> لیستی از نمونه‌های آزمون در اختیار شما قرار گرفته و نیاز است مدل شما تا حد ممکن دسته‌بندی هر کدام از آن‌ها را به‌درستی تشخیص دهد. پیشنهاد می‌کنیم برای اطمینان از عملکرد مدل خود و بهبود آن، ابتدا آن را بر روی یک مجموعه‌ی اعتبارسنجی آزمایش کنید.
# </font>
# </p>
#
#
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معیار ارزیابی
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# هدف این است که مدل شما دسته‌بندی یک محصول را با دقت بالا پیش‌بینی کند، بنابراین در این پروژه از معیار  <code>Accuracy</code> جهت ارزیابی نتایج مدل شما استفاده خواهد شد.
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font color="red"><b color='red'>توجه:</b></font>
# <font face="vazir" size=3>
#  جهت کسب امتیاز کامل نیاز است تا پاسخ شما حداقل امتیاز <code>83</code> را با توجه به معیار معرفی‌شده کسب نماید.
# </font>
# </p>

# %%
# Evaluate
# TODO

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# ساختار خروجی برای نمونه‌های آزمون
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#  پیش‌بینی مدل خود را برای نمونه‌های آزمون به‌شکل برچسبی بین ۰ تا ۱۰ تولید کرده و در ستون <code>cat_id</code> یک دیتافریم با نام <code>submission</code> در قالب جدول زیر ذخیره کنید.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |<code>image_name</code>|نام فایل تصویر (مشابه با نمونه‌ی آزمون)|
# |<code>cat_id</code>|برچسب/شناسه‌ی دسته (پیش‌بینی مدل)|
#
# </font>
# </div>
# </center>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font color="red"><b color='red'>توجه:</b></font>
# <font face="vazir" size=3>
# در تبدیل خروجی مدل به برچسب‌ها توجه داشته باشید که اگر از تابع <code>image_dataset_from_directory</code> جهت خواندن تصاویر استفاده کرده‌اید، ترتیب برچسب‌ها به آن شکلی نیست که انتظارش را داریم و به شکل زیر خواهد بود. بنابراین خروجی نورون سوم برابر پیش‌بینی برچسب ۱۰ است و نه ۲! پس اگر روی خروجی مدل تابع <code>np.argmax</code> اعمال کنید برچسب‌های درستی تولید نمی‌شود. این موضوع یکی از چالش‌های رایج در پروژه‌های دسته‌بندی تصویر است که مشاهده می‌کنیم مدل روی داده‌های آموزشی و اعتبارسنجی به‌خوبی عمل می‌کند اما در زمان آزمون عملکرد بسیار بدی از خود نشان می‌دهد و شوکه می‌شویم. دلیلش این است که نگاشت خروجی به برچسب را به‌درستی انجام نداده‌ایم.
# </font>
# </p>
#
# `['0', '1', '10', '2', '3', '4', '5', '6', '7', '8', '9']`

# %%
# Preparing submission file
submission = None # TODO
submission

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.</font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

submission.to_csv('submission.csv', index=False)
file_names = ['image_categorizer.ipynb', 'submission.csv']
compress(file_names)
# Out:
# File Paths:
# ['image_categorizer.ipynb', 'submission.csv']

# %%
submission
# Out:
#             image_name cat_id
# 0     -56lhw2AKjYI0Hnt      0
# 1     -6OdHXCBItIArPyk      2
# 2     -7241lsvPiVpNVFV      9
# 3     -8-0wltLEZBDTM5M      9
# 4     -GcrzANWUmrjk2tb      7
# ...                ...    ...
# 1196  zNIgOhLGUPCyp7vl      5
# 1197  zhzjJeI8FwQDZQCE      1
# 1198  zizDow_ExDVnz9QS      2
# 1199  znpJGKcXxvmOU_nK      0
# 1200  zxGrP8vp5fnXR5PM      9
#
# [1201 rows x 2 columns]
