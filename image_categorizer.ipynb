# %% [markdown]
# <h1 dir=rtl align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# دسته‌یاب تصویر
# </font>
# </h1>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# به پروژه‌ی دوم کالج یادگیری عمیق خوش آمدید! 🥳
# مجموعه‌داده‌ی این پروژه توسط <a href="https://torob.com/" target="_blank">ترب</a> در اختیار شما قرار گرفته و شامل بخشی از داده‌های واقعی این وب‌سایت است. همان‌طور که می‌دانید ترب یک موتور جست‌وجوی خرید است که اطلاعات هر محصول را از فروشگاه‌های آنلاین مختلف گرد هم آورده و در یک صفحه‌ی واحد نمایش می‌دهد. بنابراین کاربران قادر خواهند بود به‌راحتی محصول موردنظرشان را پیدا کرده و فروشندگان مختلف آن را مقایسه کنند. یکی از مهم‌ترین نیازمندی‌های فنی چنین پلتفرمی، تشخیص خودکار اطلاعات محصولات است، زیرا پالایش دستی این حجم از داده و استخراج اطلاعات از آن‌ها امری بسیار زمان‌گیر و هزینه‌بر خواهد بود. شاید بتوان دسته‌بندی یک محصول را مهم‌ترین اطلاعات آن دانست، زیرا که در جست‌وجوپذیری آن نقش مهمی ایفا می‌کند.  بنابراین در این پروژه به کمک ترب خواهیم آمد و یک مدل یادگیری عمیق طراحی می‌کنیم که بتواند براساس تصویر یک محصول، دسته‌بندی آن را بیابد.
# </font>
# </p>

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# به‌دلیل حجم بالای مجموعه‌داده نیاز است آن را جداگانه از <a href="https://drive.google.com/file/d/1hZK1rshl4dJVEPkUPykU5cZs_ANyTWp-/view?usp=sharing" target="_blank">این لینک</a> دانلود کرده و فایل‌های داخل آن را استخراج کنید.  توجه داشته باشید که اندازه‌ی مجموعه‌داده حدود ۲۷۰ مگابایت است و اگر قصد دانلود این حجم از داده را ندارید پیشنهاد می‌کنیم از محیط گوگل کولب استفاده کرده و به‌صورت مستقیم با دستور زیر این فایل را روی کولب خود بارگیری کنید.
# </font>
# </p>
#
# `!gdown 1hZK1rshl4dJVEPkUPykU5cZs_ANyTWp-`
#
# <details dir="rtl" style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <summary dir="rtl" style="color:orange"><b>رفع مشکل عدم امکان دانلود فایل با <code>gdown</code></b></summary>
#
# اگر در هنگام دانلود فایل به‌کمک <code>gdown</code> با خطای عدم اجازه‌ی دسترسی مواجه شدید، کافیست کد زیر را اجرا کرده و دوباره امتحان کنید.
#
# <span dir=ltr style="direction:ltr;">
#
# `!pip install --upgrade --no-cache-dir gdown`
#
# </span>
# </details>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# مجموعه‌داده‌ی این پروژه شامل ۱۱ دسته‌ی محصول مختلف است که تصاویر مربوط به نمونه‌های آموزشی هر دسته در داخل پوشه‌ای با نامی معادل با شناسه‌ی دسته در پوشه‌ی <code>train</code> قرار گرفته است. همچنین تصاویر مربوط به نمونه‌های آزمون در داخل پوشه‌ی <code>test</code> قرار دارد و مدل شما باید بتواند با ورودی گرفتن هر کدام از این تصاویر، دسته‌ی آن را تشخیص دهد.
# دسته‌های این محصولات و شناسه‌ی هر کدام در جدول زیر آمده است:‌
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# | <b>شناسه‌ی دسته</b> | <b>عنوان دسته</b> |
# | :---: | :---: |
# | <code>0</code> | کاپشن، بارانی و پالتو مردانه |
# | <code>1</code> | سویشرت و هودی مردانه |
# | <code>2</code> | ساعت مچی عقربه‌ ای و دیجیتالی |
# | <code>3</code> | ساعت دیواری، رومیزی و تزیینی |
# | <code>4</code> | لوازم جانبی ساعت معمولی و هوشمند |
# | <code>5</code> | سویشرت و هودی خردسال و نوجوان |
# | <code>6</code> | کاپشن و پالتو خردسال و نوجوان |
# | <code>7</code> | سویشرت ورزشی مردانه |
# | <code>8</code> | سویشرت و شلوار ورزشی مردانه |
# | <code>9</code> | ساک و چرخ خرید |
# | <code>10</code> | چمدان و ساک |
#
# </font>
# </div>
# </center>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در ابتدا فایل‌های مربوطه را خوانده و نحوه‌ی بارگیری تصاویر مجموعه‌داده را پیاده‌سازی کنید.
#
# </font>
# </p>

# %%
# !pip install --upgrade --no-cache-dir gdown
# Out:
# Collecting gdown
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:975: The handshake operation timed out'))': /packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:975: The handshake operation timed out'))': /packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:975: The handshake operation timed out'))': /packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:975: The handshake operation timed out'))': /packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:975: The handshake operation timed out'))': /packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Max retries exceeded with url: /packages/54/70/e07c381e6488a77094f04c85c9caf1c8008cdc30778f7019bc52e5285ef0/gdown-5.2.0-py3-none-any.whl.metadata (Caused by ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:975: The handshake operation timed out')))
#
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !gdown 1hZK1rshl4dJVEPkUPykU5cZs_ANyTWp-
# Out:
# ^C

# %%
import os
os.environ["KERAS_BACKEND"]="tensorflow"

# %%
import keras
print(keras.__version__)
# Out:
# 3.1.0

# %%
import os, glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, accuracy_score
from keras.utils import image_dataset_from_directory
from keras.applications.resnet50 import preprocess_input
import tensorflow as tf

# %%
train_dataset = image_dataset_from_directory(
    directory='./train/',
    labels='inferred',
    label_mode='categorical',
    color_mode='rgb',
    batch_size=32,
    image_size=(224,224),
    shuffle=True,
    seed=42,
    validation_split=0.2,
    subset='training')

# find the class names so in prediction time we can map the predictions to the painters properly
class_names = train_dataset.class_names
print('Class names:', class_names)

val_dataset = image_dataset_from_directory(
    directory='./train/',
    color_mode='rgb',
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(224, 224),
    validation_split=0.2,
    subset='validation',
    seed=42, # TODO
)
# Out:
# Found 8829 files belonging to 11 classes.
# Using 7064 files for training.
# Class names: ['0', '1', '10', '2', '3', '4', '5', '6', '7', '8', '9']
# Found 8829 files belonging to 11 classes.
# Using 1765 files for validation.

# %%
# loaded test data 

test_dataset = image_dataset_from_directory(
    directory='./test/',
    label_mode=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(224, 224),
    shuffle=False
)
image_names = [img.split('/')[-1] for img in test_dataset.file_paths]
test_dataset = test_dataset.map(lambda x: preprocess_input(x))
# Out:
# Found 1201 files.

# %%
# Plot images 

import matplotlib.pyplot as plt

for images, labels in train_dataset.take(1):
    # Select 12 random images
    indices = np.random.choice(images.shape[0], 12, replace=False)
    selected_images = images.numpy()[indices]

    # Plot the selected images
    plt.figure(figsize=(9, 9))
    for i, image in enumerate(selected_images):
        plt.subplot(3, 4, i + 1)
        plt.imshow(image.astype('uint8'))
        plt.axis('off')
    plt.show()

# %%
image_names
# Out:
# ['-56lhw2AKjYI0Hnt.jpg',
#  '-6OdHXCBItIArPyk.jpg',
#  '-7241lsvPiVpNVFV.jpg',
#  '-8-0wltLEZBDTM5M.jpg',
#  '-GcrzANWUmrjk2tb.jpg',
#  '-H3eW6fAmjabFQEv.jpg',
#  '-HiiXK6MB6F1u40a.jpg',
#  '-K5ftb4XBgVegcq7.jpg',
#  '-PVsEsjibQBimlP0.jpg',
#  '-Q0Yo_MTjnhzgtN9.jpg',
#  '-TBD4tIe-a5UP1mh.jpg',
#  '-Tktdo4X5LgUMvSw.jpg',
#  '-U9lVuyU3rjePU2w.jpg',
#  '-dDdmvuCoHRNvJK-.jpg',
#  '-ga31aOTDSPAk8W0.jpg',
#  '-jatHKBptixJPEQT.jpg',
#  '-o4zntf0z1Eu0IJ6.jpg',
#  '-oeDjNxexoilWeox.jpg',
#  '-u1wASthhxChx3G5.jpg',
#  '-vCVFJtJTs7YChq5.jpg',
#  '-xAm9bKdi9qTCCra.jpg',
#  '-xq0ILJth3DVCYt2.jpg',
#  '-zJwe8YBxr85Kqg9.jpg',
#  '02OB8CEAAq0oyBwZ.jpg',
#  '02VCtYpDEvYkINWl.jpg',
#  '03DAx7-4cWGuhEX5.jpg',
#  '03xupnFJ2o_2kqKa.jpg',
#  '0BgZnLHZLYz1FmtI.jpg',
#  '0E9rEioGHMxjdCWj.jpg',
#  '0EWPPBjWdTUI9GOE.jpg',
#  '0Ec2a9JMPyN8E691.jpg',
#  '0GhwqifywrmSbfZK.jpg',
#  '0KbUyXdr0ZMjaFFm.jpg',
#  '0L0u1A_aWPUVG5aH.jpg',
#  '0RJ3OX2VBHElngIk.jpg',
#  '0VAS0qijlcyjfSfW.jpg',
#  '0Z5yioYpOoNH-iRv.jpg',
#  '0jbb92ze77YgRYK7.jpg',
#  '0r-YN2GLC7NQQcGp.jpg',
#  '0ull0MeSHKGf3pJF.jpg',
#  '0umwxpjgv3xtrzyJ.jpg',
#  '0wyzNFWaH6guStX-.jpg',
#  '0xg_-CaB8YpE3LBT.jpg',
#  '0xthRPq5IQSSb0Xh.jpg',
#  '0yyLOJ-IjDC9fv90.jpg',
#  '1FRKnFTejuYLMB4w.jpg',
#  '1G0SAiYEaHRA1ZRk.jpg',
#  '1NlN_OKl40FQC3Pz.jpg',
#  '1_b3eGKt9rlVkfQt.jpg',
#  '1b6QC4gxRbieTrPC.jpg',
#  '1bHZuYTRaquFU35l.jpg',
#  '1bt2SzdBV4Sv9Fyz.jpg',
#  '1esCtoEr2qlBQxMw.jpg',
#  '1g7BfURN3jfztN-Q.jpg',
#  '1hcP_Onwgxbq8uyP.jpg',
#  '1ojSz6gySxug4DHp.jpg',
#  '1pEVArPfN1QvPqSk.jpg',
#  '1pH-N16EKKs-iYcU.jpg',
#  '1q4rveLPqBEgRgLs.jpg',
#  '1qRddJ0MKyR7dmAh.jpg',
#  '1sLiR9Y3KXzWX0Dg.jpg',
#  '1wQICTAoPSpMCs-r.jpg',
#  '1xw7gAZfNRorjXYp.jpg',
#  '21CX7zTOyJfO_tge.jpg',
#  '21bGzJQLeUfS43UE.jpg',
#  '27Tn5EuM6Gss3i6C.jpg',
#  '2CV-yQaTTcCpQGgL.jpg',
#  '2E3LUx7GEuf5jVUh.jpg',
#  '2Exudd9ynuP4SjE5.jpg',
#  '2Hl6-HEB-jax97oz.jpg',
#  '2IO65ZMkvcDhimof.jpg',
#  '2LXcxOeQF5loaMKU.jpg',
#  '2Mb1DVI3h1BTo7y0.jpg',
#  '2OQfu4AWBw1Q-S6X.jpg',
#  '2SNqYgD0XFkddQ5g.jpg',
#  '2TtoRZPDc1PGpAZl.jpg',
#  '2Y589tmFGPZ9CWay.jpg',
#  '2YMFioSZH8uJs32R.jpg',
#  '2ar95iikaE408UXR.jpg',
#  '2oVaKd7pj74DAArM.jpg',
#  '2voJsOvAEo_ohvR9.jpg',
#  '2zVBXudf8S72u94A.jpg',
#  '33XWF2uMPSW-3ds6.jpg',
#  '350o3r_cOWzvejNx.jpg',
#  '35ueVoKg3ZfZPis4.jpg',
#  '37jG7gFwZ8dTCq5J.jpg',
#  '380NqFnHx5F0pAIY.jpg',
#  '38gRTJ9AXPVw5gO_.jpg',
#  '39J6ok1q_S9plAJG.jpg',
#  '3Di2IQCZwBoPc8Vg.jpg',
#  '3H2nM8mAeWEuZpNl.jpg',
#  '3HEl8rZKMWfuM9Z7.jpg',
#  '3OCn9BBLvFQvI7e1.jpg',
#  '3O_Du8fmtfLqkPqR.jpg',
#  '3SKpchskm2eaZjzj.jpg',
#  '3YRnxcaPs4XGPPV6.jpg',
#  '3jRFhsjPnpJ0CZ11.jpg',
#  '3kU1lE-OpOrG09WS.jpg',
#  '3ltPfUmJFLRfymgR.jpg',
#  '3mrFx34SnbRqUo41.jpg',
#  '3n46pQQPTjRRfMkI.jpg',
#  '3tCT1dXLHivVYMhz.jpg',
#  '3tmAt4tvLdjBBD-I.jpg',
#  '4-gkGuKr7F2x-geV.jpg',
#  '4623DcIlkPhWNzCk.jpg',
#  '4BwPqaSGTYcnGZx5.jpg',
#  '4EI6E7xXXSnoTfwG.jpg',
#  '4HpitTseds6ei5Lu.jpg',
#  '4IWNLjibX7JUQwBx.jpg',
#  '4JN4WVIf01yRz4gZ.jpg',
#  '4MIIqUfR5VJaAfRX.jpg',
#  '4OPOjWN2qgYHgxB7.jpg',
#  '4PQC9Latb6LZxzuH.jpg',
#  '4QrgtEUQLn9D9Nbe.jpg',
#  '4USz4lnpBlJTpEX9.jpg',
#  '4XIHJrwejdi9xu6v.jpg',
#  '4ZPHQVkTnMXVKiRx.jpg',
#  '4aDfi6t7JYBJCAUO.jpg',
#  '4eRGjKhV68DAMb64.jpg',
#  '4fKZcxZH50VaI1pW.jpg',
#  '4kSy7shZ74sOlISX.jpg',
#  '4lCfEzcd_9PBtGMG.jpg',
#  '4wYTQPjehHFzenAb.jpg',
#  '55rv97OzpiiLrNh9.jpg',
#  '5AHvsAYlFCaEzJ_d.jpg',
#  '5B34C1TBGy2OID75.jpg',
#  '5FXNiTxbmLnkF-Il.jpg',
#  '5Fo7sANLPtycKigY.jpg',
#  '5KFlpVn93HU8F0m-.jpg',
#  '5PzSYcls4aLTCpFi.jpg',
#  '5YbMUSClF8-qG4UM.jpg',
#  '5_LFBBZChdeRx8Jt.jpg',
#  '5ibeXdI0_Cyfi6ba.jpg',
#  '5nq4AvGUMAfjCte1.jpg',
#  '5oybP1-Tvcdg0siH.jpg',
#  '5p2RFwdzV9YEES-i.jpg',
#  '6-h4SLZh27fVfpSR.jpg',
#  '627wbXsFizcjISB5.jpg',
#  '6ALTpgZ3A_37BsQL.jpg',
#  '6CriuPrkDM7-Kuzy.jpg',
#  '6DKd9oweg1l9yYYr.jpg',
#  '6ORxI1IO7tnWkqWI.jpg',
#  '6PAVSkZCaIwP1hhu.jpg',
#  '6Q98YXGRLxsi-nJS.jpg',
#  '6VaxrQNuRQoE_4OZ.jpg',
#  '6bZaPpg6FTXLSLAh.jpg',
#  '6g343d9_WbJW5bYN.jpg',
#  '6h-jiHLqmlrlTXZx.jpg',
#  '6kj76RY8N1B_Ps4l.jpg',
#  '6nMHUT9WtOtejPIS.jpg',
#  '6o58lIz7ialdNGuv.jpg',
#  '6qhTDhqxlso5JhSd.jpg',
#  '6rIxNAUFw93W8ZlT.jpg',
#  '6tmKD0dWyAuelc3s.jpg',
#  '6uchZQckxU45gdZx.jpg',
#  '6ynfqdiRluOVhiql.jpg',
#  '7-Y4XyaUtH9Yl8wH.jpg',
#  '75I-EqVOhy8DIsuD.jpg',
#  '79GTqQfijUkchxGS.jpg',
#  '7DjFJtmv-8a-PxUT.jpg',
#  '7J_2w0luKdWB1WUt.jpg',
#  '7WgkG_h4CEpFAEeV.jpg',
#  '7cQ3whVyNy8y4rWd.jpg',
#  '7e_vd051sCxtjur2.jpg',
#  '7edpy0rbXLrL9k6P.jpg',
#  '7gSr69PUyL2k871d.jpg',
#  '7ggtVkdUO2Z0Erhr.jpg',
#  '7im9mKkUm-pMh_gw.jpg',
#  '7p4Qy2XNlHjkQCYU.jpg',
#  '7rDfL-487RQTrMfY.jpg',
#  '7udUn9y4hGL4pr3u.jpg',
#  '7w_OYQHBroD4aZeu.jpg',
#  '8491BdlDcF27Stan.jpg',
#  '8CDsdSTxPm-oNA3H.jpg',
#  '8DAq4SiF0KZVW7PU.jpg',
#  '8NoGe49nKzWHQSNX.jpg',
#  '8PbYtOE_5ny-LAO-.jpg',
#  '8UdXVWWqvsAswLH-.jpg',
#  '8VOwS-q25wVfF4-G.jpg',
#  '8Y4LI7b5p86E23Ny.jpg',
#  '8YgkAM6GoMLRhxkl.jpg',
#  '8ckHHc4SArANwfDH.jpg',
#  '8eAlCQzM2hTKsMaP.jpg',
#  '8kJyI1i47Z4gcGiY.jpg',
#  '8lOVD83jsC0S8h2I.jpg',
#  '8qOS4e9AVMkJUs4f.jpg',
#  '8zKuLvMrfrhGOEb9.jpg',
#  '926Gm4ehygOQkQZH.jpg',
#  '94oW-L7GR7PIUD-Z.jpg',
#  '95BseBGsKuYuBmVa.jpg',
#  '96q-c7zL8sLbyU3g.jpg',
#  '980kdZQWD5xRF6rS.jpg',
#  '9CgeoBvgWM9ryMR5.jpg',
#  '9Lg-EJA2XdzoI6kJ.jpg',
#  '9X5XBnNN3_2gGKI1.jpg',
#  '9cTQUU-RMAu2L2F8.jpg',
#  '9cna8euwRfLWF5gP.jpg',
#  '9e4TJPEcSBoTkzYc.jpg',
#  '9fH2cDRbSf4hajxT.jpg',
#  '9lV4ogjliSpOoY1H.jpg',
#  '9nQmzBJwvFZeG4_P.jpg',
#  '9o4YbecojZ4Agvv1.jpg',
#  '9qvi3uZ6KrZyQMl3.jpg',
#  '9v7eXTyFSiktKsEP.jpg',
#  '9vhkxvr_rZbsqtbr.jpg',
#  'A2kK5SbbLPanWxA5.jpg',
#  'A3q4PVimJJ3dnF_W.jpg',
#  'A4uIzYujNM9yYz1x.jpg',
#  'AErWeja3C49Uhx0z.jpg',
#  'AHbwcvNx8lt8Kv5M.jpg',
#  'AKgym3dUHoyW20xW.jpg',
#  'ANARVuI9Py_n46DF.jpg',
#  'ANkQCEIW822cKd0c.jpg',
#  'ANlT6YABgQuvbDN-.jpg',
#  'AOFdcDe05AQyDill.jpg',
#  'AR2HXO1lt0IoCgnW.jpg',
#  'ARM0qzZLGjKKZC-F.jpg',
#  'AY1i0nDWZPq-oVHK.jpg',
#  'Ac-Yd275YcoP2hb5.jpg',
#  'Ahmb1XkT24WEi8yN.jpg',
#  'AiMpFTxuRUTosgTz.jpg',
#  'AimyrnebZ7V7VRBe.jpg',
#  'ApOuZhlWB32wMW57.jpg',
#  'AsRsz4jLGsQ-ZW1n.jpg',
#  'Ay3UbF83o4MeflZ9.jpg',
#  'B2n4o-LUTgRAFED9.jpg',
#  'BOYXsFtw67OJl9AB.jpg',
#  'BWQ0rmKbihUh6sxR.jpg',
#  'BdokBH4XYYXEktJI.jpg',
#  'Be7wVvq2LM1smzNM.jpg',
#  'BipjIVf5zD_Ccf0l.jpg',
#  'Bj6vta0D4JZqCCuP.jpg',
#  'BkWYGSk6Dz8cW9mX.jpg',
#  'BoX3Dwprb6qn8nFn.jpg',
#  'BouoJYGHhqLZdGA4.jpg',
#  'Bq_EuhXfM37xsatp.jpg',
#  'BrKLsP6MiFOoxnQK.jpg',
#  'Bsan0ccI_byoRjOo.jpg',
#  'Bt0JQkoFceGcmdRD.jpg',
#  'BtXWHd2tJOhb-DH4.jpg',
#  'ByVUwbPvmxsTPn8d.jpg',
#  'C4eFR4FVG6tuXQF8.jpg',
#  'CBCtLFwtpKspbtAm.jpg',
#  'CISwPOvv8SLLhW6P.jpg',
#  'CR_92lFNI59-XEo_.jpg',
#  'CXjwImFaVvfSKcmO.jpg',
#  'Cd_5uLOVim1gb8vJ.jpg',
#  'CjyoRLtC9sW4mLsf.jpg',
#  'CkK4Z0mXTU7zfVP8.jpg',
#  'Cn0wmGdJ5NZ7jLAB.jpg',
#  'CotPA7gJ1rlSWcCr.jpg',
#  'CqSON78MpqWtH3Ne.jpg',
#  'Cwioc7xOMPuCYrFq.jpg',
#  'CyLfvCs7RsAsNFeJ.jpg',
#  'D2j375h6pyVI1MdK.jpg',
#  'D3YaGTUq0cBLW22N.jpg',
#  'D6jb2EY4NdMn5vio.jpg',
#  'DA1wd98PKZbAUBxQ.jpg',
#  'DBJGJacKfMxjSwGS.jpg',
#  'DF6Z0DXQ5zOsFXLm.jpg',
#  'DFG29jW1TZ6tRAUo.jpg',
#  'DGaJ7t5uxQp-9qJd.jpg',
#  'DHTH9fypFYrMNSfd.jpg',
#  'DMuAZiWMJq96RE59.jpg',
#  'DNAD3Iu54aIdOQN2.jpg',
#  'DNJSHPBVBRxYlgT2.jpg',
#  'DNmjPbihpV1drE3L.jpg',
#  'DOkXFAr5z-62cZtz.jpg',
#  'DZ8tWlTzDSPIxlv0.jpg',
#  'Dl6dUA_P72iaV_Gk.jpg',
#  'DmZ-VcA9ZZYxm8zj.jpg',
#  'DryYrEKg9Ty0Bgb4.jpg',
#  'DstUfi-DLRRbrP3B.jpg',
#  'DtLODVkRoQKRg0O1.jpg',
#  'DuG437zzWhxT4F1C.jpg',
#  'DuuQIrqQHbK1Rzo7.jpg',
#  'DwGQuHf_CUvfnytX.jpg',
#  'E94WHDtREg_4UKx0.jpg',
#  'EDCt8y5vsVRL3lLB.jpg',
#  'EGauwIJ15F2VIQtO.jpg',
#  'EIXV8lsNugbXnuNh.jpg',
#  'EM9_I3yFs1iSgbDl.jpg',
#  'ETa1lqhM-2SA6JDI.jpg',
#  'EbKt1UMo0q2KNSMQ.jpg',
#  'EcTDPh5m43PspXm1.jpg',
#  'Ecshom3CCxgqMvWn.jpg',
#  'Edn95JAgP_say1sJ.jpg',
#  'EiUXMfXaWDkHTDgy.jpg',
#  'EnLcWfGttS1qtadr.jpg',
#  'EpQZ3frs6Uu6f0a0.jpg',
#  'EpSMyKQzHvBgobkE.jpg',
#  'Ew_VFXN1-fpyXy0m.jpg',
#  'F1FH7jMDGjGK_LYy.jpg',
#  'F6ulKoGxnp97ms9A.jpg',
#  'F8q1MSFCfo17_pFq.jpg',
#  'F9u5wOsKPxsfqx01.jpg',
#  'FB0MQJUlljHnQMbI.jpg',
#  'FCKViAr_j2bGNad-.jpg',
#  'FEdO1zGd78FI64_0.jpg',
#  'FFgpeaXufRHDg6EV.jpg',
#  'FSfoLOKV0gAcKjc4.jpg',
#  'FWQTPQoCGtlG6WOc.jpg',
#  'FX8HuVL-tPG8WQwz.jpg',
#  'FZgM49xig56LsNO4.jpg',
#  'FfojmXjNzIO3LlqK.jpg',
#  'FhgsCcPz6nUVOIga.jpg',
#  'FiI8oTUE_PLwfuTe.jpg',
#  'FiYIazKwoYvhP0RG.jpg',
#  'FmTxV2zxW9A_QOJx.jpg',
#  'FmWnvnYfagNgJyS-.jpg',
#  'FpdW4axUm7rTvvGp.jpg',
#  'Fy7RtntM4Ynl_n1-.jpg',
#  'G4YA8kYlU65kXLkf.jpg',
#  'G5gFrVCNgEPQ5KGr.jpg',
#  'G6jXcy9Dej0YLw3O.jpg',
#  'G956mLo7WkUsKXVK.jpg',
#  'GEcGAlbSdD0UoBDO.jpg',
#  'GFQ28Uo-SZVE_ZNV.jpg',
#  'GHJq6QDSfHmsCdkE.jpg',
#  'GNea0QBvf-7iRjCV.jpg',
#  'GPy_MpIHGOtAvTvA.jpg',
#  'GVA35YnRcS6PAJj6.jpg',
#  'G_EXYAaGLqPtcJF6.jpg',
#  'GeFEXm--sdo40hVC.jpg',
#  'Gky5pvr5C5pSMU-K.jpg',
#  'GnL94XPPwqljHu1f.jpg',
#  'GrdIVxJ6i9boTli-.jpg',
#  'GyrO0c-efCuNcLZU.jpg',
#  'H-7R7b1tJaTNZR2t.jpg',
#  'H4DbP_RRNnYCJqNu.jpg',
#  'H5qh4ILVheKeQTrc.jpg',
#  'HCdbMZI-FxewLSsm.jpg',
#  'HD3EIvOX5kIs1PHR.jpg',
#  'HDZyPkZYXiFfzGYc.jpg',
#  'HDqlNzKFk37cI5eL.jpg',
#  'HJM7tcM3BHjMvffl.jpg',
#  'HJxxeCjXPBuP_qVt.jpg',
#  'HKPd2YBKSbPBpYrv.jpg',
#  'HNvGp_lo0CLvRjwl.jpg',
#  'HO6W1Aug4gvjKBtD.jpg',
#  'HOa3aA84aJqJQOZe.jpg',
#  'HPSziRfdg9vO0rGE.jpg',
#  'HZ9wS0DDREpZqDKg.jpg',
#  'HZTJFrqEUYVTWsn7.jpg',
#  'HZYDZ_wOO7P-8ur0.jpg',
#  'HeHym9Lo6KWp37WH.jpg',
#  'Hf_VOJNtW4lX5FS2.jpg',
#  'Hftb2e2ndbj7Jp1k.jpg',
#  'HgyAUi75nzCR-e_Z.jpg',
#  'HqvUVlQzW0He2e4P.jpg',
#  'HrFAYUX-NSeeN9s6.jpg',
#  'HuMcd1nIfFMo_l0x.jpg',
#  'I0bpbYtAEz-StIQ4.jpg',
#  'I1sgtftgVw_aPs9L.jpg',
#  'I6FstGt0E811A_Z8.jpg',
#  'I7xm2HCcb5UDi4Z2.jpg',
#  'I8cEz9UC7Hxl1xCa.jpg',
#  'IBdi_Sq0AOvnasIm.jpg',
#  'ICp6zDvkyCn6i3Ft.jpg',
#  'IERLR88RDdUWA_xh.jpg',
#  'IINv9DBw2c21YTuw.jpg',
#  'IKVSZHhMm-jKgSrq.jpg',
#  'IQKXMoZQJX4-eMts.jpg',
#  'IQT910n-qZo410_v.jpg',
#  'IQvqEQi46_dh_WAj.jpg',
#  'ITGMBMOLPOF-Mjy4.jpg',
#  'IVgr55IuLnywnYHt.jpg',
#  'IYBkl0VTknw42B1N.jpg',
#  'I_qNyCh_b5G-NISX.jpg',
#  'IfzfVRA4Pj6HEB88.jpg',
#  'Ik17LHLFmmvPBUi1.jpg',
#  'IkOP0vRUXQ6DaNRB.jpg',
#  'InDPY7S2EuzO51Bm.jpg',
#  'Iy9-4TXwz5celvQw.jpg',
#  'J-MRBc5e5VQAe9Ct.jpg',
#  'J33ovOgW0PaDpz7W.jpg',
#  'J8w2Sua5wQh2hQt7.jpg',
#  'JCbvoazEd5yohc3v.jpg',
#  'JH9OYupOfjxZpUoN.jpg',
#  'JIk44tGexR_q-FZ6.jpg',
#  'JJ2ogtwCNWLqS1uI.jpg',
#  'JQx1PnnXs4bNIBdA.jpg',
#  'JSCLR3wxwAwfiz_a.jpg',
#  'JUd8IiDAxpgDSRiN.jpg',
#  'JYuM4XgsCj2I6qSW.jpg',
#  'Jb-S1qWsggvkbWUR.jpg',
#  'JeUP7s3k6RX1Y7Ix.jpg',
#  'Jf1pMZAj9tVWEoVg.jpg',
#  'JgL3Lxvnq5HPlye2.jpg',
#  'JkYUbpJrg65AAX2u.jpg',
#  'JlnAxatfUVo5ep4k.jpg',
#  'Jqz0QhhpeCeDK9lV.jpg',
#  'JxBgb05DE2zGdWhg.jpg',
#  'JxMyoKmynYgMf31m.jpg',
#  'K-zq9vVaKtN9XHPP.jpg',
#  'K4gYBTamBWSk8K5p.jpg',
#  'K7B7xTBjU4jOK6Zi.jpg',
#  'K9cPClfy245mbvZd.jpg',
#  'KB0h7f0DGSXuIBoV.jpg',
#  'KBET8hYJnU84DTh_.jpg',
#  'KIvtjWVHffZ4iuAf.jpg',
#  'KKobjYlZw8n_OOnu.jpg',
#  'KNbgeSPRcwDmMzdM.jpg',
#  'KQeNtBjtw_jzepQR.jpg',
#  'KRIAkvOeKW-urW5O.jpg',
#  'KS714PtfSYf7cgI3.jpg',
#  'KX77Hi6ZECJTrxiU.jpg',
#  'KaUTU-3IMwzGRqtz.jpg',
#  'Kal7ke327u_dgbIW.jpg',
#  'KbDvj-Qf7dXt543K.jpg',
#  'KknJEp_uNXapiuO-.jpg',
#  'KodKMLklKAYgvRKv.jpg',
#  'KsHw1sIZ4aLLhjae.jpg',
#  'KsZDeSIe6ysaIbYO.jpg',
#  'KuZBRfx8EGIA452d.jpg',
#  'Kw3Nvz53ijsd07XQ.jpg',
#  'Kw6Rm39RXWDNDupJ.jpg',
#  'L1FuIXyvAEGr6YC8.jpg',
#  'L1fc2XMsdVqKspsd.jpg',
#  'L2NjaL2n_VOYm-cQ.jpg',
#  'L4530sbw918whVQK.jpg',
#  'L6R-AXsc06vEmPcl.jpg',
#  'L6_lCUHVSfeOOWW6.jpg',
#  'LE4jzOzV0jEehCpP.jpg',
#  'LJ3EqcwZI81f02Sh.jpg',
#  'LKl33GM1f7B5U3LA.jpg',
#  'LNTKJY447y-eJj1g.jpg',
#  'LPs1PogzU0EftGn2.jpg',
#  'LS6Pg_1CVqSQ6hyl.jpg',
#  'LiRKvKHJuf0LT1Eb.jpg',
#  'LiXF08cvIORuIHzq.jpg',
#  'LivY_00dlfzgUujE.jpg',
#  'LkYbitBJQ-EHLbBq.jpg',
#  'LlN4kf45g13uqojV.jpg',
#  'LnuYCfl4OtK1Zerp.jpg',
#  'M3cGWXMROdcFOYkw.jpg',
#  'MBmCnhomhvMMIG7D.jpg',
#  'MIYbj9m4Mus7TDBr.jpg',
#  'MOHBuoOTK1UzbpJi.jpg',
#  'MOddGeJtjSewK7Nd.jpg',
#  'MXIgGTp7i7p1qRTK.jpg',
#  'M_Azda3NzS9SV-WU.jpg',
#  'MdD58XjqvLyqsw8-.jpg',
#  'Mpz0XiH0pic9tfx9.jpg',
#  'Mq1mxP_KTwuzdQu4.jpg',
#  'MqbYBh84jd1ikM6w.jpg',
#  'Mqq2A2To-qhfMUXo.jpg',
#  'MrWLH33aC-XA_za8.jpg',
#  'MurCBDLchmWRZySc.jpg',
#  'Mx2Cvxfc8yqxjLoh.jpg',
#  'MyjhifuP-JzQA1eA.jpg',
#  'NBQNoxISXnOxz8Xf.jpg',
#  'NG_vjb7kXtjjTAV_.jpg',
#  'NRjzSMSJxkKRwaj3.jpg',
#  'NTuE_AlK61gE_BJX.jpg',
#  'NXI54blyfgF-_iPn.jpg',
#  'NfJIk8eN3KzXgPrF.jpg',
#  'Nwlv7GSjNoS5EwDc.jpg',
#  'Nwy4-Dqc8kLBh_RP.jpg',
#  'O-BK_nIkuqIGtiap.jpg',
#  'O-EhJSPYkL8031pf.jpg',
#  'O1Q-tou5LLPLVFEn.jpg',
#  'O52XBgeuiZuJnt_c.jpg',
#  'O9-aNDUp3Rj_wNXu.jpg',
#  'OAa2qOwqWbChVCXK.jpg',
#  'OEqBoN6-79SPo7uO.jpg',
#  'OF3V2eYCyJYxSX8y.jpg',
#  'OMDLMkqFe6C4J7fy.jpg',
#  'ONMX-uxRqvrGWyzK.jpg',
#  'OP6V8U24DAn9lWKi.jpg',
#  'OPClMdy5yCx1Hbi7.jpg',
#  'OPxcsFZmUlTHYN4J.jpg',
#  'OQWQIgA3OSGRpJNv.jpg',
#  'ORHbGpCerG3KIMTl.jpg',
#  'ObRW7hvb47EJS2SV.jpg',
#  'Od8gCAgSlIj9nNbO.jpg',
#  'OenHbnQPLAlJbJqY.jpg',
#  'OlQdnHqoWB1HXTGv.jpg',
#  'Os6-8yjTA1UZZTJ6.jpg',
#  'Ou-LBqELX6-_qBBL.jpg',
#  'Owi2C-zcHKG-fr_H.jpg',
#  'P2RxXhKyRf7Fm4Nf.jpg',
#  'P5htnkQaDlVrWSxR.jpg',
#  'P6P7TvcxIXxZMKV6.jpg',
#  'P7Om9AYiYQEMP2UZ.jpg',
#  'PADRX1wKwb_U5hcs.jpg',
#  'PBK6185UKs_qUte1.jpg',
#  'PBr94wIMtCjV8FiN.jpg',
#  'PBtrhSvv8FtzjMLV.jpg',
#  'PE7lfMOg-4E09VDE.jpg',
#  'PFRZtGExjdeAavL_.jpg',
#  'PHE-ZjPb0h3KjtYt.jpg',
#  'PLnQH952QtQbtLsm.jpg',
#  'PLsnskfYHuTekHZG.jpg',
#  'PS1x7c8jolhVU01A.jpg',
#  'PT1ZJTvAzw79T_dY.jpg',
#  'PU0EtVbKwqPqKCl-.jpg',
#  'PV-pClMVmqojMM61.jpg',
#  'PkSr_jzMJtBQyxDQ.jpg',
#  'Pm8LlbQ2rhRDxpAv.jpg',
#  'Po4NCiuK7w_TIZG-.jpg',
#  'PrHz0HwUMs97lKj6.jpg',
#  'PwDYuW-MH-vVG6tx.jpg',
#  'PzaYCJejrEInmIPW.jpg',
#  'Pziu4C04oi28-kQ9.jpg',
#  'Q12XebzZtgwmdRLz.jpg',
#  'Q5HZTMOlI1eUf-bx.jpg',
#  'QETrWUxyrlcgG8T9.jpg',
#  'QIIOufzLjdpA3p-h.jpg',
#  'QPV2st2AWMrfASgU.jpg',
#  'Q_iFzrdqy-BOImvU.jpg',
#  'QgsXGMpWq3khad9R.jpg',
#  'Qkl1LpRNN_NefSdP.jpg',
#  'RBx31kiDT9v5mhRa.jpg',
#  'RHyc47MvcEfxJaIj.jpg',
#  'RIsboCBXBWOwsu6S.jpg',
#  'RPLw3khplw1Vo_tE.jpg',
#  'RQuqZWIdjTro5xoS.jpg',
#  'RRKtSnKIqtUPbBd1.jpg',
#  'RW_TSPCuup237Bb2.jpg',
#  'RZHH9mMZD38qUCzS.jpg',
#  'R_i2JNJO51osiv2q.jpg',
#  'RaFol46w1nJe_kov.jpg',
#  'ReRAJ0ZlxW2LLgm3.jpg',
#  'Rf8t48Ot_xcZr-0N.jpg',
#  'RjfeqgwInHFviUFh.jpg',
#  'RlP7hro6BlcW4rTJ.jpg',
#  'RoRxQoRnW-3MJZ-P.jpg',
#  'Ru1J-IiU_i5W6uDe.jpg',
#  'RvPnN3sZ5TyVRW8g.jpg',
#  'RziQEO-CPgwTtMo1.jpg',
#  'S0wTaqYf15_-cQAQ.jpg',
#  'S1-nbmcLR1R0P1Jh.jpg',
#  'S8363VsH7l51u0JW.jpg',
#  'S8NZJaAUc9NiUKnj.jpg',
#  'S8iueyk7PktK6ed_.jpg',
#  'S9VhD-NT2S1hPswD.jpg',
#  'SFIMYz1cqJEbyMGE.jpg',
#  'SHP0n86wP_-jHa8P.jpg',
#  'SHeGgMFvb4g87PFC.jpg',
#  'SP2fGdFcw3LQLV_P.jpg',
#  'STWrkLEKX0hjrkRk.jpg',
#  'STcBEAjaJEXFL-n_.jpg',
#  'SdoYx154-qWqOmce.jpg',
#  'SeJwyGwOSx9HAA3M.jpg',
#  'ShI9iP5Hcq8iQZHc.jpg',
#  'SikkNTkOxbFXW8__.jpg',
#  'Sj1a0pgAovl6BuCa.jpg',
#  'Sm1_8r0k7M3rxF-8.jpg',
#  'SnxM06sxIt0v83TL.jpg',
#  'Sw8B8sN_cth4RSYg.jpg',
#  'SwR5bJddkwEyvnAg.jpg',
#  'T33J7H9TdmTR85zP.jpg',
#  'T8xBLJAQ7UdbCDnq.jpg',
#  'TCAKc-IJT64-5foa.jpg',
#  'TE-DKUhoqidwGEUn.jpg',
#  'TFdFuh5Wtp80FlG8.jpg',
#  'TGjpR4vmJOdEK80Q.jpg',
#  'TJ5u75_kHoWHBvur.jpg',
#  'TJwJPXiU4gkIVdWf.jpg',
#  'TK4nargLXMpDZF94.jpg',
#  'TKJ8N9p22i7GNi5m.jpg',
#  'TLEUdz0hzz31L29f.jpg',
#  'TM5yCitnoNI0oCPr.jpg',
#  'TRB2-4c7aF_vsJ6N.jpg',
#  'TSPGOEdItgDmUHx6.jpg',
#  'TgZ0-IbnxHwAhhls.jpg',
#  'TgrRED38ttQtUAan.jpg',
#  'Tie4pCtdHYIiZi1r.jpg',
#  'TiuWnqgt2CvHFFhJ.jpg',
#  'Tj_RcEcJPTGSOxBo.jpg',
#  'Tk8z9x8auXYPn2BM.jpg',
#  'TkjZ8H-0e-FdSJlc.jpg',
#  'Tm6Hn7iR3Wjg7tt_.jpg',
#  'TrT5pFQ1DnsyWpff.jpg',
#  'Ty829M-Znv_sssa6.jpg',
#  'U4glu4-woAqyVjbT.jpg',
#  'U7qhu4k7AL_YI7Tq.jpg',
#  'U8YrcltM0XtjE9zf.jpg',
#  'U8_5TQEjPrbMKnbT.jpg',
#  'U8qLDx94zVkD0Tpv.jpg',
#  'UHBqEzoMxq4iOxG5.jpg',
#  'UJKD2orDb8NszHj6.jpg',
#  'UQ2wS1PLYGtWua9Y.jpg',
#  'US0WJLDat9iKEZSt.jpg',
#  'UUcyqkNo_HM-ebWC.jpg',
#  'Ud5dD3kO-4cvU63l.jpg',
#  'Uh3K8IJ7jOaUBOnn.jpg',
#  'UiF3DWjhO874WeUZ.jpg',
#  'UitK8Bv_7-82mXW9.jpg',
#  'Um9yLl07K0m9VKDH.jpg',
#  'Up8V7gDbLdQAftnL.jpg',
#  'V1b_fTkscLmdC5fm.jpg',
#  'V4FZQe-av52h6r36.jpg',
#  'V8LtFKuhxO2R2xQV.jpg',
#  'VAwZfn-zWA24rKDO.jpg',
#  'VBHmezUHUSzaiWCg.jpg',
#  'VMbGXaTIeyEij48h.jpg',
#  'VODvvMnkm1uQQZxL.jpg',
#  'VPbTPBr1CwC3UEwD.jpg',
#  'VVBR9uONcW3hxuVf.jpg',
#  'VVVEDQRhhPz2860r.jpg',
#  'VYcBYxPHBp6lYyP4.jpg',
#  'VZFbeyxPwe_yViPW.jpg',
#  'VZVbQ0RFtN7bROZX.jpg',
#  'VZgsVTsNPERD64d0.jpg',
#  'VbcTerWAiecU-_T5.jpg',
#  'VcdD-YWfLw-EKRP3.jpg',
#  'Vhdd3_zb0x11aZYh.jpg',
#  'VlKdd1eUZ5AEatmm.jpg',
#  'Vm-h4P2PQJV15vPW.jpg',
#  'VnOMWUc72TX9z5h-.jpg',
#  'VrBfBAIWp6WFJT7-.jpg',
#  'VrWC9y46bFXV-mzS.jpg',
#  'VrcewP8zC-loLPJ0.jpg',
#  'VuM1Bh6cjTQl60u-.jpg',
#  'VxZa9MutAOUc5zvc.jpg',
#  'VzoQaO-_7DZHdQ-o.jpg',
#  'W72PD6YAcouB-FiL.jpg',
#  'WE23pC0zk73JN07W.jpg',
#  'WFgph1pN8UahquY-.jpg',
#  'WGcnmtvUrXzMbkns.jpg',
#  'WHGlrlBuAUAuTng4.jpg',
#  'WOh_n4oB_wubjlW8.jpg',
#  'WSAuWYS0XgwjBhbB.jpg',
#  'WTRQ7oLsXbkaq33M.jpg',
#  'WVCXBERw6a9b6Q5G.jpg',
#  'WVGcjDpW2TON0ZZo.jpg',
#  'WfoB2I6tgIB8e3j8.jpg',
#  'WgXMyPXOcHO09hzo.jpg',
#  'Wkf66W7HTyTSJove.jpg',
#  'WnBfoqZVMzOOr_bk.jpg',
#  'Wq8diDtBqWfuVNeG.jpg',
#  'WtB9uciQZvFdfLRI.jpg',
#  'X1BNRo6JevZnPXAJ.jpg',
#  'X2FG6CyQQk6oftMI.jpg',
#  'X2f44zJsoiFXBnJX.jpg',
#  'X3WEspkGdJVAMBKq.jpg',
#  'X6C_LM_cpryt5nNd.jpg',
#  'X6wq174aw9BmI2SQ.jpg',
#  'X8wXu8AqxMPXBy-y.jpg',
#  'XAJsLkUzSaYW5g4n.jpg',
#  'XAPrsL-d-F2c17Sa.jpg',
#  'XAuCdsmCyucewD3m.jpg',
#  'XBH3yKbU_jAIVZF1.jpg',
#  'XD4ImTdc7O3__7zn.jpg',
#  'XHOLg02yITULLjiY.jpg',
#  'XMdt6Ijf0M5DFBOm.jpg',
#  'XMe9zNbPW6pR_pDN.jpg',
#  'XMzgeoHxZ0O8Oqec.jpg',
#  'XNpEa7TcEEuzutsi.jpg',
#  'XO4WRpylRilw6xmB.jpg',
#  'XTVQW3n29Snx_Vim.jpg',
#  'XUBWx5t5bWSp7jZT.jpg',
#  'XVuUX_8JXbJki2A2.jpg',
#  'XZxXEnpHGNKd7Pl6.jpg',
#  'XjknCRHoUaihjA8M.jpg',
#  'XlysiFNkOvyooI4L.jpg',
#  'XmBFnq-HsNw8TaGh.jpg',
#  'Xw8PMrBRWu-YzkS_.jpg',
#  'XyxOwyfX3LYAluoa.jpg',
#  'XzAw22prrpETudgg.jpg',
#  'Y-US858g5BH1mXMo.jpg',
#  'Y3wq-Lx75bO_987A.jpg',
#  'Y4bmKMgtWyTpaehI.jpg',
#  'Y6RabkpuTC-eNL4j.jpg',
#  'YAdlfMsCUe3w5l6Y.jpg',
#  'YB7WU1m-kmDfhjrg.jpg',
#  'YBBD3k33YPQsUH5E.jpg',
#  'YBa48SccnEnLeJQT.jpg',
#  'YBdovNpgKmc08J_D.jpg',
#  'YH_dv-yZB5V6uQMZ.jpg',
#  'YLduUB9y1fOlVU71.jpg',
#  'YOewutgnKiBHRZZY.jpg',
#  'YSUpek2x2hMnaCM9.jpg',
#  'Yd3OX4adbFpYPRLX.jpg',
#  'YeecROr50l0eQt-K.jpg',
#  'YfDiAmnqvM-I3ZKq.jpg',
#  'YhS8lmqlwA9kf2TE.jpg',
#  'YhvuFNaZ9HKsrHRV.jpg',
#  'YsUW5vslxYTsHPcw.jpg',
#  'Z1-Lxtn08bhoqwCR.jpg',
#  'Z4CK3eZU0rpsAk8R.jpg',
#  'Z7uelPbw9UgdYjUn.jpg',
#  'Z9l-a5dsMn3873Uu.jpg',
#  'ZKTwUoZYvxtbAb_j.jpg',
#  'ZLnZ4eNyNsqibVtf.jpg',
#  'ZNBFMS2CV5K495l8.jpg',
#  'ZSQwF1Me-j5ZV_xL.jpg',
#  'ZTt0xOx48oLI_VEp.jpg',
#  'ZXrLU3okF1vwew2z.jpg',
#  'ZcYYFHwHwiBrCC89.jpg',
#  'Ze29sVAC_KGEUJTr.jpg',
#  'ZeE2Mv6WtokRebQp.jpg',
#  'ZfEJABLz81gEJZFL.jpg',
#  'ZiBKN7k9qgkz6CmA.jpg',
#  'Zllc49cjw1kCJDSB.jpg',
#  'ZmuY2cJEwrOjTSYH.jpg',
#  'ZnGd2r2hEVFMG-Bk.jpg',
#  'Zoj7yt6UdsOpukfS.jpg',
#  'ZqyzTOdr9uAGxuhU.jpg',
#  'Zr3a8yi9rAEUuGhr.jpg',
#  'ZrRbpcktuj9GWcIK.jpg',
#  'ZsP7dO1ZXae9vIkb.jpg',
#  'Ztq2OCiRKeqiW0cF.jpg',
#  'Zxsti3rf-tUeXFZ2.jpg',
#  '_-_K2eqZhHDOwZvh.jpg',
#  '_4IrR0yhl21gQJC_.jpg',
#  '_5YFxLhFwGYSIgsc.jpg',
#  '_6skJ-ev8mdRVvGB.jpg',
#  '_943MVifa3ars_IH.jpg',
#  '_EBUL7Spyo_V1jy1.jpg',
#  '_Hcb145r4APSCmQc.jpg',
#  '_MrqzvbI3-MGeKsd.jpg',
#  '_N-x7yIPgyWzJU2G.jpg',
#  '_QL6CiuXlIIb-JY2.jpg',
#  '_WajlMwUDtI3lsZS.jpg',
#  '_Xrx9f_4DZKreKSA.jpg',
#  '_e2mVi98Mcn9Vn9l.jpg',
#  '_eKDb1gw3WzE70mj.jpg',
#  '_eiZbeEPqC2MVHff.jpg',
#  '_jAG9GTzHxnUUi60.jpg',
#  '_quX9iNaxeDlgG71.jpg',
#  '_wrz8lr6uTXldAzh.jpg',
#  'a2-6Kx2APx9LetQG.jpg',
#  'a32cAtNzr4M-j8s2.jpg',
#  'a70IODXn9p1F_-n2.jpg',
#  'aBcDR-tXIGQ8KoGQ.jpg',
#  'aGBcax1l33c15uZP.jpg',
#  'aKMK_7dmFb9DjbY5.jpg',
#  'aKoXOOoNaXhG4WSj.jpg',
#  'aMKpGFE6QdAmQuHf.jpg',
#  'aNtYH-q_he2rYgqQ.jpg',
#  'aSuel9dbdVIfSC32.jpg',
#  'aU1gwjoz-WiHgm8N.jpg',
#  'aVzEkjO28rYHfOCV.jpg',
#  'aa8_Hh3jAu8EBnP6.jpg',
#  'aaGLoqAf8c419-KO.jpg',
#  'adVJJzrkhgxRvCSg.jpg',
#  'akVo4ymIVkxhZa8k.jpg',
#  'ar8b2a7kKNCOluzW.jpg',
#  'at0bcsBmmbc5ETLK.jpg',
#  'avn76kWZr1qLTEP5.jpg',
#  'b1zHYAw1c1-ac1IC.jpg',
#  'b5pHQ84NKTffMCPQ.jpg',
#  'b9btDG_EA5qFpnYj.jpg',
#  'bCU-9BhPB8iM-PTp.jpg',
#  'bEEMuhdWjLrV0ed4.jpg',
#  'bRgLHDmMAM5VprB7.jpg',
#  'bUgPq3yi__DQIM4P.jpg',
#  'bX0OLhDYhqRuNhFm.jpg',
#  'bYMWcWETne4kxkYh.jpg',
#  'bZwD8zUZ4GM-WRpo.jpg',
#  'bbXO-TCuSME42gWD.jpg',
#  'bhqQRaSmg_VAs_Il.jpg',
#  'bixEQqZqNXsYx9Ao.jpg',
#  'bkuSkFsVDBNPcHb2.jpg',
#  'blC3wcN23ENbkTDp.jpg',
#  'brm_rdPY1myLMAfe.jpg',
#  'bsnF7t72aVPEwp2W.jpg',
#  'bx1_wH9vFhqvQcV1.jpg',
#  'bxg8Zt-oGZsnneAm.jpg',
#  'byCNff2jRr5PwqPc.jpg',
#  'c3bDajyBbdMRMUxz.jpg',
#  'cDvaq48VqszcNORL.jpg',
#  'cE6WMpv0im6KGFaM.jpg',
#  'cO9-3epDeWkqCmUt.jpg',
#  'cTrm9LIeuzOpV26i.jpg',
#  'cVEfOHA6TBRkwaqD.jpg',
#  'cVnncGaXQqYAPchj.jpg',
#  'cXVBhsBaS9hYymZz.jpg',
#  'cYhK8AwDi1JBEL1q.jpg',
#  'cdQHHAGjCiefjmgl.jpg',
#  'cdxFr_oCh6akvhD7.jpg',
#  'ceLK05O6ijwYV1bV.jpg',
#  'ciWWzM7x-Aykcfyh.jpg',
#  'cjAOGXY-Dmif2zxy.jpg',
#  'clHC_kJrGbuebPWC.jpg',
#  'czx1KSd1l5gWTtw3.jpg',
#  'd2QfAVdtRHTgmvgx.jpg',
#  'd3PQyYrZ7rjPUwEq.jpg',
#  'd6B7auIGqaqkcUcT.jpg',
#  'd7KGsw5tgJtcJtyL.jpg',
#  'd9I-S4LprrdlidsU.jpg',
#  'dGZ2uA99tK9HbS_e.jpg',
#  'dICxk2RnbLig789P.jpg',
#  'dIbXW98MAkE1J9n1.jpg',
#  'dJYSzf3kCWqn3XuI.jpg',
#  'dQ2YNm3SkSg-1GMz.jpg',
#  'dS52D1B7bgjV_3D4.jpg',
#  'dUlAvnOJhTVSiEYF.jpg',
#  'dV32SyY2jduZNFsN.jpg',
#  'dVcbQ7QfhVgYed2V.jpg',
#  'd_cETczNPjSPfLAl.jpg',
#  'dawIjKI4aUPa9sIF.jpg',
#  'dfC0iEDHkgt8vcpR.jpg',
#  'djcamuifUHzWGChA.jpg',
#  'dl_J86axaELfdTKr.jpg',
#  'dmtYOAS4aQeAaJ1C.jpg',
#  'dobA1omUtPz0K1sd.jpg',
#  'dog5g8is9XWbWOVv.jpg',
#  'dvSG_52oN3DJu-ts.jpg',
#  'dyvHqst4XWp32xAz.jpg',
#  'dz6vI-cFBJxae0JE.jpg',
#  'e-bPwq_oHrxLc8_0.jpg',
#  'e2uRX2ku2YKOUX6A.jpg',
#  'eEJ2_FgI8KeP9MQ-.jpg',
#  'eHwxnEn9FqPT_8UC.jpg',
#  'eKIFdpuPWWbLLTrV.jpg',
#  'eL2f_9A4KHE0eInr.jpg',
#  'eN6olfwO0xoXM88a.jpg',
#  'ej5R6MSbhkTYPgbT.jpg',
#  'eo1qYOE4yMBs0Xws.jpg',
#  'epYXUX--3wJbp82x.jpg',
#  'es0yPv2cmWsWCMSE.jpg',
#  'es2XIP2ccHmkSvRQ.jpg',
#  'ewSs3XS-c3YzQ9CF.jpg',
#  'eyfOCwbdrZvkGTpa.jpg',
#  'ezq3lFXlc6s811Xk.jpg',
#  'f5jDNl6nuiFvujZy.jpg',
#  'fH5scO6-q_d2BM9F.jpg',
#  'fL1Hah8gKM7VtbwC.jpg',
#  'fPpmrkEJCpiICCOS.jpg',
#  'fz9DpEohmKPmYVNi.jpg',
#  'g0o_ZHqlvyJQu6sw.jpg',
#  'g7CEv40pMDMKOiNb.jpg',
#  'gABGT1CoWD8CER4a.jpg',
#  'gAaWF9fQrP0w30Bm.jpg',
#  'gBMkEesrKZ1CWPR2.jpg',
#  'gCkCYLqmXvPaJe8i.jpg',
#  'gD1cZ4DxzTbIUfA_.jpg',
#  'gDNEilJat25x79y5.jpg',
#  'gEbe4a0ao-ut8nC5.jpg',
#  'gGDLejoVpSGX9hJ3.jpg',
#  'gHdJKoD0LdK0l1Q8.jpg',
#  'gKN29l6AcENpxLdn.jpg',
#  'gS3ZLbf2yRSmC5AE.jpg',
#  'gSlvDkV1qPy16_tO.jpg',
#  'gT5VQky6qwdeyTOs.jpg',
#  'gZK_vgNYF-X_PMyl.jpg',
#  'gb9MdCei75EcYp-t.jpg',
#  'gcMP5xJpxGzWy32F.jpg',
#  'gcPVRtzhvbo3CE-6.jpg',
#  'gf9J6KBZ93RPXoIq.jpg',
#  'giJ4T92mTGkLdBul.jpg',
#  'gjjp7UUF3Sn1pCKq.jpg',
#  'gqO4xVtp-a4in7Mn.jpg',
#  'gsSj-hoM4W9YVmsr.jpg',
#  'gvRgGKhT3X4NaIaO.jpg',
#  'gvvln0OIQgGamT2P.jpg',
#  'h0MkS8ictRE-qYCr.jpg',
#  'hEWHqSQL-O4YYCb9.jpg',
#  'hKLKV9v_IZuSov-P.jpg',
#  'hKUc-GDD134AmAUr.jpg',
#  'hWZN5vl_Y_c8nqGa.jpg',
#  'hXx535BVnPx5vIPw.jpg',
#  'hZuQK47sZvYDjoI5.jpg',
#  'hb4jg1RSse_3t3kU.jpg',
#  'hivAAcGProj-Kf59.jpg',
#  'hroXa7nYoElasU8X.jpg',
#  'hxkUYq1Y3GPz5HwP.jpg',
#  'hyudCSy8n6lvubGx.jpg',
#  'i0ELKUNiwHiallQG.jpg',
#  'i39xBp8eTpzh_S5R.jpg',
#  'i3cOs7pjXUxdqE0h.jpg',
#  'i3jCCygYc4SiipEf.jpg',
#  'i7KEpiRUSbsf-PO8.jpg',
#  'i7mHVw2AVgMHcjOr.jpg',
#  'i9mN00ODPA_6vwS3.jpg',
#  'iGpPTHFWFnfAgvGi.jpg',
#  'iJuvTGJjf1_S4WAV.jpg',
#  'iK-gbcFfVex89oBZ.jpg',
#  'iLeb0nSuYlm5SwJS.jpg',
#  'iMeEPgyLb-dOJRps.jpg',
#  'iPNgnDIwJmsKPTVI.jpg',
#  'iT0_5lP2HiAvmjBX.jpg',
#  'iUBylvH05TBCD-Pl.jpg',
#  'iWEAiMiGJnq_BJHZ.jpg',
#  'iXWRVPCoNKq56HeA.jpg',
#  'iZZ4sGt7iNkj0w_G.jpg',
#  'idUMZESXmE75l8Lp.jpg',
#  'idfp7natdejZVx_L.jpg',
#  'ihUBgkCEorEBWi0V.jpg',
#  'imHDFc9w2o-hsws4.jpg',
#  'in51JrYky2jW8-Si.jpg',
#  'iqUiwh_twmh48rVB.jpg',
#  'j0u8giLVqgGIfKcJ.jpg',
#  'j5JyyAvwBr2uWues.jpg',
#  'j6i8xE1cvcpfqevL.jpg',
#  'jAQGvL7r9Wi4mp7k.jpg',
#  'jDPKQkCbNRvDRQGT.jpg',
#  'jJ0GN18yZjjKc00-.jpg',
#  'jLP5RFmES80HnW3X.jpg',
#  'jUDhcx1LwKuJyjkm.jpg',
#  'jVcyrjfOIL01V_NX.jpg',
#  'j_ov3-BfKiIF-Odv.jpg',
#  'jcc8ZHFs11r9x6ev.jpg',
#  'jdlZXmSf3Bj7YrUX.jpg',
#  'jhy6C56SNOEd3B2d.jpg',
#  'jvRdmWcK7sjL0gT7.jpg',
#  'jz8wG4gotiG2P1t1.jpg',
#  'kAWhOMMDGZno1gKD.jpg',
#  'kCbW5yT4YwOjrz9Z.jpg',
#  'kGW49xTLTmAH7-dZ.jpg',
#  'kLSK0hTeo7Eios-l.jpg',
#  'kP1m6OfgxvqzP_jH.jpg',
#  'kRX3rKsX8tDjYY2_.jpg',
#  'kVBal-DyEbHtI2y7.jpg',
#  'kWbMUxGeQwUQndCp.jpg',
#  'kYyu6yuyDk7GxYfB.jpg',
#  'k_1Jpq7J3IdOfHWl.jpg',
#  'kcSw_pOBefUV8huz.jpg',
#  'kcchX_xctTciA38A.jpg',
#  'kmWRBkTlNoFIfUB5.jpg',
#  'knctHvqi8Bk1e2RT.jpg',
#  'koYyjY5JLKpsRnGe.jpg',
#  'ktXA0heFSXy1sTHQ.jpg',
#  'kuIsiy0ygleQ1_h_.jpg',
#  'kw_7vRHn6Mso0R5N.jpg',
#  'l-qX_MLDuHlR6NRE.jpg',
#  'l2yk5L_yIqD7ks59.jpg',
#  'l44TxUUj_s0pF3MJ.jpg',
#  'l9Bk5VXQmM8d26t3.jpg',
#  'l9d8ONvlW0IWj2Iz.jpg',
#  'lENUBBuzOk-2ytul.jpg',
#  'lMbT3BMbZSrboe2d.jpg',
#  'lNn04ALTGMHQrAzw.jpg',
#  'lTPnJaJP0_3IpRQ1.jpg',
#  'lXq8769zRWSaHwq1.jpg',
#  'lYOmpuqUI9MEKCw4.jpg',
#  'l_7yvVHmY_venrbd.jpg',
#  'lcQuJpLnai61obSk.jpg',
#  'lh1P5_mvsibO9vKZ.jpg',
#  'lhVjUZa3Ewl8cg5Q.jpg',
#  'lo7tegsQ5uuVJNuv.jpg',
#  'lovgPqTavpVaI-Cp.jpg',
#  'lqUe8_y45YVg7x9Z.jpg',
#  'lzpMi9u2-hK80Wwz.jpg',
#  'm0F2pe6AW0Lk6xpd.jpg',
#  'm0OJ95NJImCETPIA.jpg',
#  'm0YodyzUZ_FxXMNe.jpg',
#  'm2neIwIuNy_ue3nU.jpg',
#  'm4uis2bVeFOFE3tl.jpg',
#  'mAv3fcd_OXHLFI7V.jpg',
#  'mDuH45cwUTYpZPXq.jpg',
#  'mKVKnmiV29EndroL.jpg',
#  'mMOT6I86w5xv1lIv.jpg',
#  'mVoLD0Q7TNFcji8Y.jpg',
#  'mVr-EhdaDlS8cw1F.jpg',
#  'mXVCGhxFVFm3UQzM.jpg',
#  'mZ85OqnzeY3bElLC.jpg',
#  'mbB0GkwmYMFfELpN.jpg',
#  'mc4UFdKIAuzZQdGR.jpg',
#  'mcq-ee8CM7ysdryF.jpg',
#  'mjIUfbsl2fxQnApA.jpg',
#  'mm9bY2H6iGn-pTiE.jpg',
#  'mrjB1xj7-Ztlz4hu.jpg',
#  'msIeP9LJeUlejVN9.jpg',
#  'msf7r2SMbcfWQhH5.jpg',
#  'mtg-EF9GBDnUeKws.jpg',
#  'mxAyqDI78Sshe3nR.jpg',
#  'mxLcgCmWhcdESBjW.jpg',
#  'my8jjODNU-UZDn_m.jpg',
#  'n08fRXHtTSUsaal8.jpg',
#  'n2Hy6XY5dTyiLK_i.jpg',
#  'nBLqWe8OqQi_LsVf.jpg',
#  'nITVWpyeTVveHQ50.jpg',
#  'nIXcxGPVhxrA-UDu.jpg',
#  'nNDyAlROhT0ROePQ.jpg',
#  'nOV4-JklUvxd2zav.jpg',
#  'nP7BZdU8iYX1pSGp.jpg',
#  'nPaDFUdDhncqnkyW.jpg',
#  'nU8Lg88_z1TjpS0b.jpg',
#  'nXxymLiyMsz75st7.jpg',
#  'ndDHO9nrj2wucyec.jpg',
#  'nizhfa1ZCTVvOmsP.jpg',
#  'njUcRRtmO5dHdQTe.jpg',
#  'nmpTiijT1cnJXRSL.jpg',
#  'nq3P6g9WeRUmShaX.jpg',
#  'nqlwSrJ3HStZzYmW.jpg',
#  'ntL-gnmI0NCHl9Oc.jpg',
#  'nv1SGwWvRw9MJu2k.jpg',
#  'nws25twa280bgL3_.jpg',
#  'nx68Uii-bw8LNZAa.jpg',
#  'nySap6289i8P6vBb.jpg',
#  'o08idUAfuSEOo4UA.jpg',
#  'o12TMnXbEHffq95h.jpg',
#  'oA21flEivhSwJdnS.jpg',
#  'oB8MA-Y6-IsnrBA8.jpg',
#  'oHG8v8mNTR7xCwI_.jpg',
#  'oIGGo4fPfK5TYEpO.jpg',
#  'oOmM5Ad5l33A_ifr.jpg',
#  'oQeHlJXGGC98n7jb.jpg',
#  'oWxS8OqIlrK0I_46.jpg',
#  'o_2eM-ZMaHp-TikF.jpg',
#  'ofDBNlbHTD10Me6Q.jpg',
#  'ok0Q3X77GzRg7wU1.jpg',
#  'omecYj6yFieFlfIf.jpg',
#  'omg6pabR8T1_ew5X.jpg',
#  'onGf9nCIuJNyKknE.jpg',
#  ...]

# %%
train_dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 11), dtype=tf.float32, name=None))>

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal')
])

def preprocess_and_augment(image, label):
    image = data_augmentation(image)  # Apply random flip
    image = preprocess_input(image)   # Apply ResNet50 preprocessing
    return image, label

# %%
train_dataset = train_dataset.map(preprocess_and_augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
train_dataset = train_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
val_dataset = val_dataset.map(preprocess_and_augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
val_dataset = val_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
model = keras.applications.ResNet50(weights='imagenet', 
                                    include_top=False, 
                                    input_shape=(224, 224, 3),
                                    pooling= 'avg')
model.trainable = False

x = model.output
x = keras.layers.Flatten()(model.output)
x = tf.keras.layers.Dense(512, activation='relu')(x)
x = tf.keras.layers.Dropout(0.6)(x)
output = tf.keras.layers.Dense(11, activation='softmax')(x)
model = tf.keras.Model(inputs=model.input, outputs=output)

# %%
model.compile(optimizer='adam', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history =model.fit(
    train_dataset,
    validation_data=val_dataset, 
    epochs=10, 
    batch_size=32
)
# Out:
# Epoch 1/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 856s 4s/step - accuracy: 0.6034 - loss: 1.3055 - val_accuracy: 0.8142 - val_loss: 0.5323
# Epoch 2/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 682s 3s/step - accuracy: 0.7902 - loss: 0.6349 - val_accuracy: 0.8278 - val_loss: 0.5107
# Epoch 3/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 681s 3s/step - accuracy: 0.8091 - loss: 0.5703 - val_accuracy: 0.8340 - val_loss: 0.4836
# Epoch 4/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 688s 3s/step - accuracy: 0.8290 - loss: 0.5045 - val_accuracy: 0.8465 - val_loss: 0.4354
# Epoch 5/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 681s 3s/step - accuracy: 0.8466 - loss: 0.4570 - val_accuracy: 0.8561 - val_loss: 0.4307
# Epoch 6/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 681s 3s/step - accuracy: 0.8576 - loss: 0.4391 - val_accuracy: 0.8555 - val_loss: 0.4236
# Epoch 7/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 678s 3s/step - accuracy: 0.8573 - loss: 0.4103 - val_accuracy: 0.8544 - val_loss: 0.4284
# Epoch 8/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 679s 3s/step - accuracy: 0.8664 - loss: 0.3883 - val_accuracy: 0.8595 - val_loss: 0.4627
# Epoch 9/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 680s 3s/step - accuracy: 0.8721 - loss: 0.3954 - val_accuracy: 0.8561 - val_loss: 0.4352
# Epoch 10/10
# 221/221 ━━━━━━━━━━━━━━━━━━━━ 679s 3s/step - accuracy: 0.8848 - loss: 0.3468 - val_accuracy: 0.8578 - val_loss: 0.4467

# %%
predictions = model.predict(test_dataset)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step

# %%
predicted_indices = np.argmax(predictions, axis=1)
predicted_labels = [class_names[idx] for idx in predicted_indices]

# %%
submission = pd.DataFrame(columns=['image_name', 'cat_id'])
submission['image_name'] = image_names
submission['cat_id'] = predicted_labels

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در این پروژه کاملاً دست‌تان باز است تا ساختارهای دلخواه خود را پیاده و آزمایش کنید. می‌توانید یک شبکه‌ی عصبی کانولوشنی طراحی کنید و از تکنیک‌های رایج این نوع شبکه‌ها بهره ببرید تا به مدلی با عملکرد مناسب دست یابید، یا می‌توانید از یک شبکه‌ی پیش‌آموخته کمک گرفته و تصمیم بگیرید که چه لایه‌هایی را به آن اضافه کنید یا چه بخش‌هایی از آن را فریز کرده یا آموزش دهید. همچنین استفاده از تکنیک‌های دیگری که در فصل بهینه‌سازی و هایپرپارامتر آموخته‌اید را فراموش نکنید.
# </font>
# </p>

# %%
# Model design
# TODO

# %% [markdown]
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌بینی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در فایل <code>torob_test.csv</code> لیستی از نمونه‌های آزمون در اختیار شما قرار گرفته و نیاز است مدل شما تا حد ممکن دسته‌بندی هر کدام از آن‌ها را به‌درستی تشخیص دهد. پیشنهاد می‌کنیم برای اطمینان از عملکرد مدل خود و بهبود آن، ابتدا آن را بر روی یک مجموعه‌ی اعتبارسنجی آزمایش کنید.
# </font>
# </p>
#
#
# <h3 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معیار ارزیابی
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# هدف این است که مدل شما دسته‌بندی یک محصول را با دقت بالا پیش‌بینی کند، بنابراین در این پروژه از معیار  <code>Accuracy</code> جهت ارزیابی نتایج مدل شما استفاده خواهد شد.
# </font>
# </p>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font color="red"><b color='red'>توجه:</b></font>
# <font face="vazir" size=3>
#  جهت کسب امتیاز کامل نیاز است تا پاسخ شما حداقل امتیاز <code>83</code> را با توجه به معیار معرفی‌شده کسب نماید.
# </font>
# </p>

# %%
# Evaluate
# TODO

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# ساختار خروجی برای نمونه‌های آزمون
# </font>
# </h3>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#  پیش‌بینی مدل خود را برای نمونه‌های آزمون به‌شکل برچسبی بین ۰ تا ۱۰ تولید کرده و در ستون <code>cat_id</code> یک دیتافریم با نام <code>submission</code> در قالب جدول زیر ذخیره کنید.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |<code>image_name</code>|نام فایل تصویر (مشابه با نمونه‌ی آزمون)|
# |<code>cat_id</code>|برچسب/شناسه‌ی دسته (پیش‌بینی مدل)|
#
# </font>
# </div>
# </center>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font color="red"><b color='red'>توجه:</b></font>
# <font face="vazir" size=3>
# در تبدیل خروجی مدل به برچسب‌ها توجه داشته باشید که اگر از تابع <code>image_dataset_from_directory</code> جهت خواندن تصاویر استفاده کرده‌اید، ترتیب برچسب‌ها به آن شکلی نیست که انتظارش را داریم و به شکل زیر خواهد بود. بنابراین خروجی نورون سوم برابر پیش‌بینی برچسب ۱۰ است و نه ۲! پس اگر روی خروجی مدل تابع <code>np.argmax</code> اعمال کنید برچسب‌های درستی تولید نمی‌شود. این موضوع یکی از چالش‌های رایج در پروژه‌های دسته‌بندی تصویر است که مشاهده می‌کنیم مدل روی داده‌های آموزشی و اعتبارسنجی به‌خوبی عمل می‌کند اما در زمان آزمون عملکرد بسیار بدی از خود نشان می‌دهد و شوکه می‌شویم. دلیلش این است که نگاشت خروجی به برچسب را به‌درستی انجام نداده‌ایم.
# </font>
# </p>
#
# `['0', '1', '10', '2', '3', '4', '5', '6', '7', '8', '9']`

# %%
# Preparing submission file
submission = None # TODO
submission

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.</font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

submission.to_csv('submission.csv', index=False)
file_names = ['image_categorizer.ipynb', 'submission.csv']
compress(file_names)
# Out:
# File Paths:
# ['image_categorizer.ipynb', 'submission.csv']

# %%
submission
# Out:
#                 image_name cat_id
# 0     -56lhw2AKjYI0Hnt.jpg      0
# 1     -6OdHXCBItIArPyk.jpg      2
# 2     -7241lsvPiVpNVFV.jpg      9
# 3     -8-0wltLEZBDTM5M.jpg      9
# 4     -GcrzANWUmrjk2tb.jpg      7
# ...                    ...    ...
# 1196  zNIgOhLGUPCyp7vl.jpg      3
# 1197  zhzjJeI8FwQDZQCE.jpg      1
# 1198  zizDow_ExDVnz9QS.jpg      2
# 1199  znpJGKcXxvmOU_nK.jpg      0
# 1200  zxGrP8vp5fnXR5PM.jpg      9
#
# [1201 rows x 2 columns]
